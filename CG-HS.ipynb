# %%
import numpy as np
from numpy import linalg as la
from scipy import sparse
import pandas as pd
import seaborn as sns
import src.normFunc as nf
import src.cg as CG
import scipy.sparse as sparse
from src.utility import make_plot

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
PATH = "./matrix/"

# %%
M1 = np.loadtxt(PATH + 'M1.txt')
M2 = np.loadtxt(PATH + 'M2.txt')
M3 = np.loadtxt(PATH + 'M3.txt')
M4 = np.loadtxt(PATH + 'M4.txt')
M5 = np.loadtxt(PATH + 'M5.txt')

# %% [markdown]
# # Experiments on Matrix M1

# %%
f = nf.Norm(M1)

# %%
initial_vector = f.init_x()

# %%
norm = la.norm(M1, ord=2) ** 2

# %%
optimizerCG = CG.conjugateGradient(f, initial_vector, 1e-5, norm, method='HS', verbose = True)
gradientsCG, normsCG, errorsCG = optimizerCG.run(500)
# Out:
# [start]
# iteration 1, f(x) = 744.3727, ||gradient(f(x))|| = 1274.151695, alpha=0.0931, rate=0.0000
# iteration 2, f(x) = 853.8054, ||gradient(f(x))|| = 273.919323, alpha=0.2267, rate=0.4717
# iteration 3, f(x) = 905.4132, ||gradient(f(x))|| = 64.547339, alpha=0.4495, rate=0.5930
# iteration 4, f(x) = 925.8769, ||gradient(f(x))|| = 21.481964, alpha=0.7170, rate=0.6763
# iteration 5, f(x) = 936.2288, ||gradient(f(x))|| = 12.052230, alpha=1.0679, rate=0.8102
# iteration 6, f(x) = 946.6720, ||gradient(f(x))|| = 8.278693, alpha=2.0358, rate=0.8815
# iteration 7, f(x) = 955.9971, ||gradient(f(x))|| = 5.476932, alpha=2.8010, rate=0.8644
# iteration 8, f(x) = 968.6134, ||gradient(f(x))|| = 3.125590, alpha=6.8926, rate=0.8599
# iteration 9, f(x) = 981.2753, ||gradient(f(x))|| = 1.070025, alpha=12.6657, rate=0.7795
# iteration 10, f(x) = 991.6279, ||gradient(f(x))|| = 0.311677, alpha=28.2796, rate=0.7161
# iteration 11, f(x) = 999.5335, ||gradient(f(x))|| = 0.121441, alpha=73.0141, rate=0.6759
# iteration 12, f(x) = 1005.8834, ||gradient(f(x))|| = 0.038295, alpha=150.5796, rate=0.6339
# iteration 13, f(x) = 1009.8507, ||gradient(f(x))|| = 0.010362, alpha=279.4001, rate=0.5360
# iteration 14, f(x) = 1011.8469, ||gradient(f(x))|| = 0.002726, alpha=480.3145, rate=0.4592
# iteration 15, f(x) = 1012.6520, ||gradient(f(x))|| = 0.000685, alpha=680.3686, rate=0.4073
# iteration 16, f(x) = 1012.9250, ||gradient(f(x))|| = 0.000234, alpha=862.0190, rate=0.4132
# iteration 17, f(x) = 1013.0498, ||gradient(f(x))|| = 0.000154, alpha=1117.0623, rate=0.5184
# iteration 18, f(x) = 1013.1360, ||gradient(f(x))|| = 0.000080, alpha=1163.7376, rate=0.5754
# iteration 19, f(x) = 1013.1777, ||gradient(f(x))|| = 0.000034, alpha=1060.6904, rate=0.4907
# iteration 20, f(x) = 1013.1965, ||gradient(f(x))|| = 0.000016, alpha=1100.7701, rate=0.4971
# iteration 21, f(x) = 1013.2052, ||gradient(f(x))|| = 0.000008, alpha=1130.6937, rate=0.5447
# iteration 22, f(x) = 1013.2098, ||gradient(f(x))|| = 0.000005, alpha=1209.4696, rate=0.6105
# iteration 23, f(x) = 1013.2132, ||gradient(f(x))|| = 0.000004, alpha=1412.5259, rate=0.6655
# iteration 24, f(x) = 1013.2156, ||gradient(f(x))|| = 0.000002, alpha=1212.0438, rate=0.6235
# iteration 25, f(x) = 1013.2168, ||gradient(f(x))|| = 0.000001, alpha=1214.7497, rate=0.5939
# iteration 26, f(x) = 1013.2177, ||gradient(f(x))|| = 0.000001, alpha=1300.6158, rate=0.6185
# iteration 27, f(x) = 1013.2182, ||gradient(f(x))|| = 0.000000, alpha=1265.1417, rate=0.5932
# iteration 28, f(x) = 1013.2185, ||gradient(f(x))|| = 0.000000, alpha=1190.4169, rate=0.5692
# iteration 29, f(x) = 1013.2187, ||gradient(f(x))|| = 0.000000, alpha=1235.8227, rate=0.5803
# iteration 30, f(x) = 1013.2188, ||gradient(f(x))|| = 0.000000, alpha=1224.6232, rate=0.5915
# iteration 31, f(x) = 1013.2189, ||gradient(f(x))|| = 0.000000, alpha=1172.2312, rate=0.5699
# iteration 32, f(x) = 1013.2189, ||gradient(f(x))|| = 0.000000, alpha=1168.1507, rate=0.5871
# iteration 33, f(x) = 1013.2189, ||gradient(f(x))|| = 0.000000, alpha=1273.2263, rate=0.6323
# iteration 34, f(x) = 1013.2189, ||gradient(f(x))|| = 0.000000, alpha=1351.3133, rate=0.6620
# iteration 35, f(x) = 1013.2189, ||gradient(f(x))|| = 0.000000, alpha=1381.9754, rate=0.6493
# iteration 36, f(x) = 1013.2189, ||gradient(f(x))|| = 0.000000, alpha=1219.8461, rate=0.5858
# iteration 37, f(x) = 1013.2189, ||gradient(f(x))|| = 0.000000, alpha=1204.4851, rate=0.5440
# iteration 38, f(x) = 1013.2189, ||gradient(f(x))|| = 0.000000, alpha=1120.9715, rate=0.5247
# iteration 39, f(x) = 1013.2189, ||gradient(f(x))|| = 0.000000, alpha=1119.6681, rate=0.5366
# iteration 40, f(x) = 1013.2189, ||gradient(f(x))|| = 0.000000, alpha=1219.9616, rate=0.6184
# iteration 41, f(x) = 1013.2189, ||gradient(f(x))|| = 0.000000, alpha=1386.5369, rate=0.6722
# iteration 42, f(x) = 1013.2189, ||gradient(f(x))|| = 0.000000, alpha=1317.5596, rate=0.6532
# iteration 43, f(x) = 1013.2189, ||gradient(f(x))|| = 0.000000, alpha=1224.0584, rate=0.6049
# iteration 44, f(x) = 1013.2189, ||gradient(f(x))|| = 0.000000, alpha=1220.4442, rate=0.5922
# optimal value reached
# [end]

# %%
make_plot(gradientsCG, errorsCG, plot_path='CG-HS/', type='M1')

# %% [raw]
# %%timeit -r 100 -n 10
# f = nf.Norm(M1)
# optimizerCG = CG.conjugateGradient(f, 1e-5, 500, x=initial_vector, verbose = False)
# gradientCG, normsCG = optimizerCG.ConjugateGradient()

# %% [raw]
# from scipy.optimize import minimize

# %% [raw]
# %%timeit -r 100 -n 10
# res = minimize(f.func_, initial_vector, method='CG', jac=f.func_grad_, tol=1e-5, options = {'maxiter' : 500})
# value = -res.fun

# %% [markdown]
# # Experiments on Matrix M2

# %%
errorsCG = []
gradientsCG = []

# %%
f = nf.Norm(M2)

# %%
initial_vector = f.init_x()

# %%
norm = la.norm(M2, ord=2) ** 2

# %%
optimizerCG = CG.conjugateGradient(f, initial_vector, 1e-5, norm, method='HS', verbose = True)
gradientsCG, normsCG, errorsCG = optimizerCG.run(500)
# Out:
# [start]
# iteration 1, f(x) = 2351.6662, ||gradient(f(x))|| = 5092.236102, alpha=0.0232, rate=0.0000
# iteration 2, f(x) = 2466.4735, ||gradient(f(x))|| = 1431.042076, alpha=0.0548, rate=0.5086
# iteration 3, f(x) = 2522.0991, ||gradient(f(x))|| = 647.111834, alpha=0.0913, rate=0.6056
# iteration 4, f(x) = 2574.8538, ||gradient(f(x))|| = 263.832685, alpha=0.2120, rate=0.6844
# iteration 5, f(x) = 2601.4777, ||gradient(f(x))|| = 67.458071, alpha=0.2443, rate=0.5627
# iteration 6, f(x) = 2614.1961, ||gradient(f(x))|| = 28.461712, alpha=0.4281, rate=0.6078
# iteration 7, f(x) = 2622.8235, ||gradient(f(x))|| = 16.273869, alpha=0.6864, rate=0.6918
# iteration 8, f(x) = 2629.9387, ||gradient(f(x))|| = 8.915225, alpha=1.0099, rate=0.6977
# iteration 9, f(x) = 2634.9312, ||gradient(f(x))|| = 5.592347, alpha=1.2858, rate=0.6427
# iteration 10, f(x) = 2639.0450, ||gradient(f(x))|| = 2.642437, alpha=1.7008, rate=0.6099
# iteration 11, f(x) = 2641.3525, ||gradient(f(x))|| = 0.902492, alpha=1.9431, rate=0.4730
# iteration 12, f(x) = 2642.2905, ||gradient(f(x))|| = 0.270226, alpha=2.2045, rate=0.3751
# iteration 13, f(x) = 2642.6252, ||gradient(f(x))|| = 0.079188, alpha=2.5466, rate=0.3229
# iteration 14, f(x) = 2642.6996, ||gradient(f(x))|| = 0.016728, alpha=1.8929, rate=0.2517
# iteration 15, f(x) = 2642.7193, ||gradient(f(x))|| = 0.004939, alpha=2.3624, rate=0.3393
# iteration 16, f(x) = 2642.7259, ||gradient(f(x))|| = 0.002499, alpha=2.6614, rate=0.4839
# iteration 17, f(x) = 2642.7301, ||gradient(f(x))|| = 0.002198, alpha=3.4003, rate=0.6448
# iteration 18, f(x) = 2642.7337, ||gradient(f(x))|| = 0.001857, alpha=3.2444, rate=0.6438
# iteration 19, f(x) = 2642.7366, ||gradient(f(x))|| = 0.000799, alpha=3.1715, rate=0.5357
# iteration 20, f(x) = 2642.7375, ||gradient(f(x))|| = 0.000165, alpha=2.0432, rate=0.2842
# iteration 21, f(x) = 2642.7376, ||gradient(f(x))|| = 0.000044, alpha=2.1626, rate=0.3014
# iteration 22, f(x) = 2642.7377, ||gradient(f(x))|| = 0.000028, alpha=2.6252, rate=0.4948
# iteration 23, f(x) = 2642.7377, ||gradient(f(x))|| = 0.000023, alpha=3.4032, rate=0.6675
# iteration 24, f(x) = 2642.7378, ||gradient(f(x))|| = 0.000013, alpha=3.2818, rate=0.5858
# iteration 25, f(x) = 2642.7378, ||gradient(f(x))|| = 0.000006, alpha=2.8030, rate=0.4423
# iteration 26, f(x) = 2642.7378, ||gradient(f(x))|| = 0.000002, alpha=2.4026, rate=0.3851
# iteration 27, f(x) = 2642.7378, ||gradient(f(x))|| = 0.000001, alpha=2.1934, rate=0.3734
# iteration 28, f(x) = 2642.7378, ||gradient(f(x))|| = 0.000000, alpha=2.7770, rate=0.4404
# iteration 29, f(x) = 2642.7378, ||gradient(f(x))|| = 0.000000, alpha=2.7927, rate=0.5195
# iteration 30, f(x) = 2642.7378, ||gradient(f(x))|| = 0.000000, alpha=2.5323, rate=0.5366
# iteration 31, f(x) = 2642.7378, ||gradient(f(x))|| = 0.000000, alpha=3.0127, rate=0.6109
# iteration 32, f(x) = 2642.7378, ||gradient(f(x))|| = 0.000000, alpha=3.6446, rate=0.6056
# iteration 33, f(x) = 2642.7378, ||gradient(f(x))|| = 0.000000, alpha=2.8117, rate=0.4985
# iteration 34, f(x) = 2642.7378, ||gradient(f(x))|| = 0.000000, alpha=2.7663, rate=0.4208
# iteration 35, f(x) = 2642.7378, ||gradient(f(x))|| = 0.000000, alpha=2.2110, rate=0.3362
# iteration 36, f(x) = 2642.7378, ||gradient(f(x))|| = 0.000000, alpha=2.0732, rate=0.3145
# iteration 37, f(x) = 2642.7378, ||gradient(f(x))|| = 0.000000, alpha=2.3236, rate=0.3124
# iteration 38, f(x) = 2642.7378, ||gradient(f(x))|| = 0.000000, alpha=2.9275, rate=0.6112
# iteration 39, f(x) = 2642.7378, ||gradient(f(x))|| = 0.000000, alpha=3.3737, rate=0.6983
# iteration 40, f(x) = 2642.7378, ||gradient(f(x))|| = 0.000000, alpha=3.9738, rate=0.6336
# optimal value reached
# [end]

# %%
make_plot(gradientsCG, errorsCG, plot_path='CG-HS/', type='M2')

# %% [raw]
# %%timeit -r 100 -n 10
# f = nf.Norm(M2)
# optimizerCG = CG.conjugateGradient(f, 1e-5, 500, x=initial_vector, verbose = False)
# gradientCG, normsCG = optimizerCG.ConjugateGradient()

# %% [raw]
# from scipy.optimize import minimize

# %% [raw]
# %%timeit -r 100 -n 10
# res = minimize(f.func_, initial_vector, method='CG', jac=f.func_grad_, tol=1e-5, options = {'maxiter' : 500})
# value = -res.fun

# %% [markdown]
# # Experiments on Matrix M3

# %%
errorsCG = []
gradientsCG = []

# %%
f = nf.Norm(M3)

# %%
initial_vector = f.init_x()

# %%
norm = la.norm(M3, ord=2) ** 2

# %%
optimizerCG = CG.conjugateGradient(f, initial_vector, 1e-5, norm, method='HS', verbose = True)
gradientsCG, normsCG, errorsCG = optimizerCG.run(500)
# Out:
# [start]
# iteration 1, f(x) = 595.2448, ||gradient(f(x))|| = 414.264367, alpha=0.1244, rate=0.0000
# iteration 2, f(x) = 641.8824, ||gradient(f(x))|| = 66.712385, alpha=0.3144, rate=0.4890
# iteration 3, f(x) = 662.2638, ||gradient(f(x))|| = 18.198497, alpha=0.7074, rate=0.4313
# iteration 4, f(x) = 669.8854, ||gradient(f(x))|| = 5.120730, alpha=0.9322, rate=0.4238
# iteration 5, f(x) = 672.4330, ||gradient(f(x))|| = 2.104443, alpha=1.0559, rate=0.4916
# iteration 6, f(x) = 674.3074, ||gradient(f(x))|| = 1.457898, alpha=1.9006, rate=0.6544
# iteration 7, f(x) = 675.8323, ||gradient(f(x))|| = 0.764214, alpha=2.2692, rate=0.6114
# iteration 8, f(x) = 676.5680, ||gradient(f(x))|| = 0.252191, alpha=2.0390, rate=0.4829
# iteration 9, f(x) = 676.8502, ||gradient(f(x))|| = 0.158223, alpha=2.3057, rate=0.4834
# iteration 10, f(x) = 677.1207, ||gradient(f(x))|| = 0.111103, alpha=3.5372, rate=0.5900
# iteration 11, f(x) = 677.2250, ||gradient(f(x))|| = 0.025067, alpha=1.9093, rate=0.3341
# iteration 12, f(x) = 677.2487, ||gradient(f(x))|| = 0.005437, alpha=1.8978, rate=0.2313
# iteration 13, f(x) = 677.2543, ||gradient(f(x))|| = 0.001051, alpha=2.0529, rate=0.2456
# iteration 14, f(x) = 677.2553, ||gradient(f(x))|| = 0.000350, alpha=2.0254, rate=0.2770
# iteration 15, f(x) = 677.2558, ||gradient(f(x))|| = 0.000154, alpha=2.4019, rate=0.5019
# iteration 16, f(x) = 677.2560, ||gradient(f(x))|| = 0.000123, alpha=3.6108, rate=0.6082
# iteration 17, f(x) = 677.2562, ||gradient(f(x))|| = 0.000082, alpha=2.7960, rate=0.5734
# iteration 18, f(x) = 677.2563, ||gradient(f(x))|| = 0.000041, alpha=2.4610, rate=0.5385
# iteration 19, f(x) = 677.2564, ||gradient(f(x))|| = 0.000023, alpha=2.9869, rate=0.4984
# iteration 20, f(x) = 677.2564, ||gradient(f(x))|| = 0.000008, alpha=2.2718, rate=0.3884
# iteration 21, f(x) = 677.2564, ||gradient(f(x))|| = 0.000002, alpha=2.2838, rate=0.3205
# iteration 22, f(x) = 677.2564, ||gradient(f(x))|| = 0.000000, alpha=2.0688, rate=0.2612
# iteration 23, f(x) = 677.2564, ||gradient(f(x))|| = 0.000000, alpha=2.0531, rate=0.2594
# iteration 24, f(x) = 677.2564, ||gradient(f(x))|| = 0.000000, alpha=2.2276, rate=0.4418
# iteration 25, f(x) = 677.2564, ||gradient(f(x))|| = 0.000000, alpha=2.6631, rate=0.6152
# iteration 26, f(x) = 677.2564, ||gradient(f(x))|| = 0.000000, alpha=3.3620, rate=0.6043
# iteration 27, f(x) = 677.2564, ||gradient(f(x))|| = 0.000000, alpha=2.9396, rate=0.5452
# iteration 28, f(x) = 677.2564, ||gradient(f(x))|| = 0.000000, alpha=2.6325, rate=0.4841
# iteration 29, f(x) = 677.2564, ||gradient(f(x))|| = 0.000000, alpha=2.4763, rate=0.4046
# iteration 30, f(x) = 677.2564, ||gradient(f(x))|| = 0.000000, alpha=2.3831, rate=0.3673
# iteration 31, f(x) = 677.2564, ||gradient(f(x))|| = 0.000000, alpha=2.0791, rate=0.3407
# iteration 32, f(x) = 677.2564, ||gradient(f(x))|| = 0.000000, alpha=2.2486, rate=0.3686
# iteration 33, f(x) = 677.2564, ||gradient(f(x))|| = 0.000000, alpha=2.2113, rate=0.3482
# optimal value reached
# [end]

# %%
make_plot(gradientsCG, errorsCG, plot_path='CG-HS/', type='M3')

# %% [raw]
# %%timeit -r 100 -n 10
# f = nf.Norm(M3)
# optimizerCG = CG.conjugateGradient(f, 1e-5, 500, x=initial_vector, verbose = False)
# gradientCG, normsCG = optimizerCG.ConjugateGradient()

# %% [raw]
# from scipy.optimize import minimize

# %% [raw]
# %%timeit -r 100 -n 10
# res = minimize(f.func_, initial_vector, method='CG', jac=f.func_grad_, tol=1e-5, options = {'maxiter' : 500})
# value = -res.fun

# %% [markdown]
# # Experiments on Matrix M4

# %%
errorsCG = []
gradientsCG = []

# %%
f = nf.Norm(M4)

# %%
initial_vector = f.init_x()

# %%
norm = la.norm(M4, ord=2) ** 2

# %%
optimizerCG = CG.conjugateGradient(f, initial_vector, 1e-5, norm, method='HS', verbose = True)
gradientsCG, normsCG, errorsCG = optimizerCG.run(500)
# Out:
# [start]
# iteration 1, f(x) = 2100.7278, ||gradient(f(x))|| = 12.064315, alpha=5.7248, rate=0.0000
# iteration 2, f(x) = 2318.0941, ||gradient(f(x))|| = 2.857416, alpha=40.1959, rate=0.2122
# iteration 3, f(x) = 2456.4768, ||gradient(f(x))|| = 1.024958, alpha=131.0358, rate=0.6046
# iteration 4, f(x) = 2547.8611, ||gradient(f(x))|| = 0.248169, alpha=241.8667, rate=0.5837
# iteration 5, f(x) = 2569.0979, ||gradient(f(x))|| = 0.173183, alpha=186.6166, rate=0.5290
# iteration 6, f(x) = 2586.9327, ||gradient(f(x))|| = 0.054692, alpha=225.5633, rate=0.7931
# iteration 7, f(x) = 2603.5197, ||gradient(f(x))|| = 0.027402, alpha=694.7631, rate=0.7810
# iteration 8, f(x) = 2609.3581, ||gradient(f(x))|| = 0.032683, alpha=458.6515, rate=0.7391
# iteration 9, f(x) = 2621.7758, ||gradient(f(x))|| = 0.014310, alpha=921.1997, rate=0.8758
# iteration 10, f(x) = 2630.2968, ||gradient(f(x))|| = 0.014092, alpha=1455.0344, rate=0.6983
# iteration 11, f(x) = 2636.9407, ||gradient(f(x))|| = 0.004473, alpha=1120.7796, rate=0.7035
# iteration 12, f(x) = 2642.9638, ||gradient(f(x))|| = 0.002318, alpha=3367.6788, rate=0.6714
# iteration 13, f(x) = 2645.4222, ||gradient(f(x))|| = 0.000963, alpha=2376.5384, rate=0.5564
# iteration 14, f(x) = 2647.8880, ||gradient(f(x))|| = 0.000427, alpha=5927.8442, rate=0.6746
# iteration 15, f(x) = 2648.8450, ||gradient(f(x))|| = 0.000277, alpha=4823.6779, rate=0.5161
# iteration 16, f(x) = 2649.6370, ||gradient(f(x))|| = 0.000088, alpha=6129.5926, rate=0.6361
# iteration 17, f(x) = 2649.9890, ||gradient(f(x))|| = 0.000073, alpha=8348.3860, rate=0.5266
# iteration 18, f(x) = 2650.1987, ||gradient(f(x))|| = 0.000030, alpha=5909.2940, rate=0.6003
# iteration 19, f(x) = 2650.3531, ||gradient(f(x))|| = 0.000019, alpha=10546.8816, rate=0.6035
# iteration 20, f(x) = 2650.4102, ||gradient(f(x))|| = 0.000010, alpha=5998.7222, rate=0.5161
# iteration 21, f(x) = 2650.4516, ||gradient(f(x))|| = 0.000004, alpha=8588.5200, rate=0.6533
# iteration 22, f(x) = 2650.4681, ||gradient(f(x))|| = 0.000004, alpha=8528.4483, rate=0.6146
# iteration 23, f(x) = 2650.4837, ||gradient(f(x))|| = 0.000002, alpha=8616.4620, rate=0.7508
# iteration 24, f(x) = 2650.4975, ||gradient(f(x))|| = 0.000002, alpha=11085.2205, rate=0.6856
# iteration 25, f(x) = 2650.5038, ||gradient(f(x))|| = 0.000001, alpha=6886.2397, rate=0.5945
# iteration 26, f(x) = 2650.5089, ||gradient(f(x))|| = 0.000000, alpha=8740.7508, rate=0.6870
# iteration 27, f(x) = 2650.5113, ||gradient(f(x))|| = 0.000001, alpha=9651.5639, rate=0.6375
# iteration 28, f(x) = 2650.5134, ||gradient(f(x))|| = 0.000000, alpha=8052.3469, rate=0.7312
# iteration 29, f(x) = 2650.5152, ||gradient(f(x))|| = 0.000000, alpha=11529.7406, rate=0.6670
# iteration 30, f(x) = 2650.5160, ||gradient(f(x))|| = 0.000000, alpha=6756.9064, rate=0.5960
# iteration 31, f(x) = 2650.5167, ||gradient(f(x))|| = 0.000000, alpha=9001.0767, rate=0.6704
# iteration 32, f(x) = 2650.5171, ||gradient(f(x))|| = 0.000000, alpha=10476.2214, rate=0.6288
# iteration 33, f(x) = 2650.5174, ||gradient(f(x))|| = 0.000000, alpha=6954.1468, rate=0.6230
# iteration 34, f(x) = 2650.5175, ||gradient(f(x))|| = 0.000000, alpha=10292.5812, rate=0.5771
# iteration 35, f(x) = 2650.5176, ||gradient(f(x))|| = 0.000000, alpha=6344.7606, rate=0.5355
# iteration 36, f(x) = 2650.5177, ||gradient(f(x))|| = 0.000000, alpha=8701.8704, rate=0.6689
# iteration 37, f(x) = 2650.5177, ||gradient(f(x))|| = 0.000000, alpha=8371.2309, rate=0.6419
# iteration 38, f(x) = 2650.5177, ||gradient(f(x))|| = 0.000000, alpha=8112.9141, rate=0.7813
# iteration 39, f(x) = 2650.5177, ||gradient(f(x))|| = 0.000000, alpha=13602.5731, rate=0.7784
# iteration 40, f(x) = 2650.5177, ||gradient(f(x))|| = 0.000000, alpha=7979.5252, rate=0.6726
# iteration 41, f(x) = 2650.5177, ||gradient(f(x))|| = 0.000000, alpha=10297.0170, rate=0.6857
# iteration 42, f(x) = 2650.5177, ||gradient(f(x))|| = 0.000000, alpha=8748.9201, rate=0.4902
# iteration 43, f(x) = 2650.5177, ||gradient(f(x))|| = 0.000000, alpha=5858.2452, rate=0.4854
# iteration 44, f(x) = 2650.5177, ||gradient(f(x))|| = 0.000000, alpha=9314.2789, rate=0.5109
# iteration 45, f(x) = 2650.5177, ||gradient(f(x))|| = 0.000000, alpha=6550.2802, rate=0.5752
# optimal value reached
# [end]

# %%
make_plot(gradientsCG, errorsCG, plot_path='CG-HS/', type='M4')

# %% [raw]
# %%timeit -r 100 -n 10
# f = nf.Norm(M4)
# optimizerCG = CG.conjugateGradient(f, 1e-5, 500, x=initial_vector, verbose = False)
# gradientCG, normsCG = optimizerCG.ConjugateGradient()

# %% [raw]
# from scipy.optimize import minimize

# %% [raw]
# %%timeit -r 100 -n 10
# res = minimize(f.func_, initial_vector, method='CG', jac=f.func_grad_, tol=1e-5, options = {'maxiter' : 500})
# value = -res.fun

# %% [markdown]
# # Experiments on Matrix M5

# %%
errorsCG = []
gradientsCG = []

# %%
f = nf.Norm(M5)

# %%
initial_vector = f.init_x()

# %%
norm = la.norm(M5, ord=2) ** 2

# %%
optimizerCG = CG.conjugateGradient(f, initial_vector, 1e-5, norm, method='HS', verbose = True)
gradientsCG, normsCG, errorsCG = optimizerCG.run(500)
# Out:
# [start]
# iteration 1, f(x) = 64587.2714, ||gradient(f(x))|| = 92816.428987, alpha=0.1719, rate=0.0000
# iteration 2, f(x) = 83206.5964, ||gradient(f(x))|| = 14407.336875, alpha=0.5648, rate=0.3586
# iteration 3, f(x) = 90772.3732, ||gradient(f(x))|| = 4298.288448, alpha=1.2591, rate=0.4742
# iteration 4, f(x) = 95830.1647, ||gradient(f(x))|| = 1667.849298, alpha=2.9372, rate=0.5495
# iteration 5, f(x) = 98527.9140, ||gradient(f(x))|| = 399.379931, alpha=3.9037, rate=0.4519
# iteration 6, f(x) = 99494.1187, ||gradient(f(x))|| = 97.717912, alpha=5.3464, rate=0.3530
# iteration 7, f(x) = 99795.9361, ||gradient(f(x))|| = 28.112738, alpha=6.4821, rate=0.3436
# iteration 8, f(x) = 99901.0702, ||gradient(f(x))|| = 11.505244, alpha=7.6578, rate=0.4034
# iteration 9, f(x) = 99949.8717, ||gradient(f(x))|| = 5.906223, alpha=8.6006, rate=0.4848
# iteration 10, f(x) = 99974.3680, ||gradient(f(x))|| = 2.590525, alpha=8.3643, rate=0.5067
# iteration 11, f(x) = 99985.4953, ||gradient(f(x))|| = 1.198974, alpha=8.6291, rate=0.5113
# iteration 12, f(x) = 99991.0896, ||gradient(f(x))|| = 0.765323, alpha=9.3557, rate=0.5659
# iteration 13, f(x) = 99994.9969, ||gradient(f(x))|| = 0.465671, alpha=10.2315, rate=0.6143
# iteration 14, f(x) = 99997.1597, ||gradient(f(x))|| = 0.280275, alpha=9.3008, rate=0.5615
# iteration 15, f(x) = 99998.4994, ||gradient(f(x))|| = 0.140979, alpha=9.5684, rate=0.5677
# iteration 16, f(x) = 99999.0887, ||gradient(f(x))|| = 0.061249, alpha=8.3646, rate=0.5283
# iteration 17, f(x) = 99999.3674, ||gradient(f(x))|| = 0.037424, alpha=9.1016, rate=0.6073
# iteration 18, f(x) = 99999.5750, ||gradient(f(x))|| = 0.029782, alpha=11.0976, rate=0.6942
# iteration 19, f(x) = 99999.7423, ||gradient(f(x))|| = 0.026349, alpha=11.2387, rate=0.6718
# iteration 20, f(x) = 99999.8862, ||gradient(f(x))|| = 0.016906, alpha=10.9214, rate=0.6063
# iteration 21, f(x) = 99999.9569, ||gradient(f(x))|| = 0.006437, alpha=8.3603, rate=0.4416
# iteration 22, f(x) = 99999.9822, ||gradient(f(x))|| = 0.002785, alpha=7.8824, rate=0.3790
# iteration 23, f(x) = 99999.9944, ||gradient(f(x))|| = 0.001034, alpha=8.7111, rate=0.4118
# iteration 24, f(x) = 99999.9982, ||gradient(f(x))|| = 0.000306, alpha=7.3207, rate=0.3170
# iteration 25, f(x) = 99999.9993, ||gradient(f(x))|| = 0.000090, alpha=7.1656, rate=0.3277
# iteration 26, f(x) = 99999.9996, ||gradient(f(x))|| = 0.000046, alpha=8.3496, rate=0.4057
# iteration 27, f(x) = 99999.9998, ||gradient(f(x))|| = 0.000022, alpha=9.6089, rate=0.4993
# iteration 28, f(x) = 99999.9999, ||gradient(f(x))|| = 0.000008, alpha=7.6779, rate=0.4048
# iteration 29, f(x) = 100000.0000, ||gradient(f(x))|| = 0.000004, alpha=8.5154, rate=0.4395
# iteration 30, f(x) = 100000.0000, ||gradient(f(x))|| = 0.000002, alpha=9.5169, rate=0.5144
# iteration 31, f(x) = 100000.0000, ||gradient(f(x))|| = 0.000001, alpha=7.7586, rate=0.4646
# iteration 32, f(x) = 100000.0000, ||gradient(f(x))|| = 0.000000, alpha=9.7988, rate=0.5297
# iteration 33, f(x) = 100000.0000, ||gradient(f(x))|| = 0.000000, alpha=9.4749, rate=0.5586
# iteration 34, f(x) = 100000.0000, ||gradient(f(x))|| = 0.000000, alpha=8.3886, rate=0.5147
# iteration 35, f(x) = 100000.0000, ||gradient(f(x))|| = 0.000000, alpha=10.1351, rate=0.5684
# iteration 36, f(x) = 100000.0000, ||gradient(f(x))|| = 0.000000, alpha=8.8033, rate=0.5578
# iteration 37, f(x) = 100000.0000, ||gradient(f(x))|| = 0.000000, alpha=9.7848, rate=0.5758
# iteration 38, f(x) = 100000.0000, ||gradient(f(x))|| = 0.000000, alpha=8.6033, rate=0.6030
# iteration 39, f(x) = 100000.0000, ||gradient(f(x))|| = 0.000000, alpha=10.0407, rate=0.6478
# iteration 40, f(x) = 100000.0000, ||gradient(f(x))|| = 0.000000, alpha=12.3390, rate=0.7017
# iteration 41, f(x) = 100000.0000, ||gradient(f(x))|| = 0.000000, alpha=10.1895, rate=0.6093
# iteration 42, f(x) = 100000.0000, ||gradient(f(x))|| = 0.000000, alpha=8.9614, rate=0.4904
# iteration 43, f(x) = 100000.0000, ||gradient(f(x))|| = 0.000000, alpha=9.2055, rate=0.4847
# iteration 44, f(x) = 100000.0000, ||gradient(f(x))|| = 0.000000, alpha=7.8423, rate=0.4340
# iteration 45, f(x) = 100000.0000, ||gradient(f(x))|| = 0.000000, alpha=9.4982, rate=0.4436
# iteration 46, f(x) = 100000.0000, ||gradient(f(x))|| = 0.000000, alpha=8.9000, rate=0.4310
# optimal value reached
# [end]

# %%
make_plot(gradientsCG, errorsCG, plot_path='CG-HS/', type='M5')

# %% [raw]
# %%timeit -r 100 -n 10
# f = nf.Norm(M5)
# optimizerCG = CG.conjugateGradient(f, 1e-5, 500, x=initial_vector, verbose = False)
# gradientCG, normsCG = optimizerCG.ConjugateGradient()

# %% [raw]
# from scipy.optimize import minimize

# %% [raw]
# %%timeit -r 100 -n 10
# res = minimize(f.func_, initial_vector, method='CG', jac=f.func_grad_, tol=1e-5, options = {'maxiter' : 500})
# value = -res.fun
