# %%
import numpy as np
from numpy import linalg as la
from scipy import sparse
import pandas as pd
import seaborn as sns
import src.normFunction as nf
import src.cg as CG
import scipy.sparse as sparse
from src.utility import make_plot

# %%
PATH = "./matrix/"

# %%
M1 = np.loadtxt(PATH + 'M1.txt')
M2 = np.loadtxt(PATH + 'M2.txt')
M3 = np.loadtxt(PATH + 'M3.txt')
M4 = np.loadtxt(PATH + 'M4.txt')
M5 = np.loadtxt(PATH + 'M5.txt')

# %% [markdown]
# # Experiments on Matrix M1

# %%
errorsCG = []
gradientsCG = []

# %%
f = nf.normFunction(M1)

# %%
initial_vector = f.init_x()

# %%
optimizerCG = CG.conjugateGradient(f, 1e-5, 500, method='HS', x=initial_vector, verbose = True)
gradientCG, normsCG = optimizerCG.ConjugateGradient()
# Out:
# Iteration number 1, -f(x) = 451.5170, gradientNorm = 80.997677
# Iteration number 2, -f(x) = 814.8388, gradientNorm = 33.606940
# Iteration number 3, -f(x) = 920.4469, gradientNorm = 13.503892
# Iteration number 4, -f(x) = 951.9337, gradientNorm = 7.549399
# Iteration number 5, -f(x) = 961.8863, gradientNorm = 5.171684
# Iteration number 6, -f(x) = 966.4458, gradientNorm = 3.985795
# Iteration number 7, -f(x) = 969.3538, gradientNorm = 3.391946
# Iteration number 8, -f(x) = 971.2926, gradientNorm = 2.810825
# Iteration number 9, -f(x) = 972.8224, gradientNorm = 2.663629
# Iteration number 10, -f(x) = 974.0064, gradientNorm = 2.249130
# Iteration number 11, -f(x) = 975.0358, gradientNorm = 2.299808
# Iteration number 12, -f(x) = 975.9130, gradientNorm = 1.969080
# Iteration number 13, -f(x) = 976.7417, gradientNorm = 2.160533
# Iteration number 14, -f(x) = 977.5137, gradientNorm = 1.877440
# Iteration number 15, -f(x) = 978.3035, gradientNorm = 2.196768
# Iteration number 16, -f(x) = 979.0975, gradientNorm = 1.922014
# Iteration number 17, -f(x) = 979.9608, gradientNorm = 2.365428
# Iteration number 18, -f(x) = 980.8715, gradientNorm = 2.054093
# Iteration number 19, -f(x) = 981.8941, gradientNorm = 2.619221
# Iteration number 20, -f(x) = 982.9926, gradientNorm = 2.227207
# Iteration number 21, -f(x) = 984.2359, gradientNorm = 2.910636
# Iteration number 22, -f(x) = 985.5656, gradientNorm = 2.398908
# Iteration number 23, -f(x) = 987.0569, gradientNorm = 3.191997
# Iteration number 24, -f(x) = 988.6209, gradientNorm = 2.530507
# Iteration number 25, -f(x) = 990.3389, gradientNorm = 3.415227
# Iteration number 26, -f(x) = 992.0876, gradientNorm = 2.589243
# Iteration number 27, -f(x) = 993.9534, gradientNorm = 3.536950
# Iteration number 28, -f(x) = 995.7843, gradientNorm = 2.554195
# Iteration number 29, -f(x) = 997.6710, gradientNorm = 3.528532
# Iteration number 30, -f(x) = 999.4502, gradientNorm = 2.422419
# Iteration number 31, -f(x) = 1001.2156, gradientNorm = 3.385114
# Iteration number 32, -f(x) = 1002.8160, gradientNorm = 2.210027
# Iteration number 33, -f(x) = 1004.3446, gradientNorm = 3.126842
# Iteration number 34, -f(x) = 1005.6814, gradientNorm = 1.946087
# Iteration number 35, -f(x) = 1006.9129, gradientNorm = 2.790753
# Iteration number 36, -f(x) = 1007.9575, gradientNorm = 1.662629
# Iteration number 37, -f(x) = 1008.8891, gradientNorm = 2.418321
# Iteration number 38, -f(x) = 1009.6604, gradientNorm = 1.386236
# Iteration number 39, -f(x) = 1010.3294, gradientNorm = 2.045203
# Iteration number 40, -f(x) = 1010.8731, gradientNorm = 1.134267
# Iteration number 41, -f(x) = 1011.3340, gradientNorm = 1.696348
# Iteration number 42, -f(x) = 1011.7035, gradientNorm = 0.915194
# Iteration number 43, -f(x) = 1012.0109, gradientNorm = 1.385797
# Iteration number 44, -f(x) = 1012.2551, gradientNorm = 0.730963
# Iteration number 45, -f(x) = 1012.4552, gradientNorm = 1.118967
# Iteration number 46, -f(x) = 1012.6131, gradientNorm = 0.579594
# Iteration number 47, -f(x) = 1012.7410, gradientNorm = 0.895538
# Iteration number 48, -f(x) = 1012.8415, gradientNorm = 0.457219
# Iteration number 49, -f(x) = 1012.9222, gradientNorm = 0.711945
# Iteration number 50, -f(x) = 1012.9854, gradientNorm = 0.359387
# Iteration number 51, -f(x) = 1013.0357, gradientNorm = 0.563157
# Iteration number 52, -f(x) = 1013.0751, gradientNorm = 0.281776
# Iteration number 53, -f(x) = 1013.1063, gradientNorm = 0.443794
# Iteration number 54, -f(x) = 1013.1307, gradientNorm = 0.220537
# Iteration number 55, -f(x) = 1013.1499, gradientNorm = 0.348751
# Iteration number 56, -f(x) = 1013.1649, gradientNorm = 0.172393
# Iteration number 57, -f(x) = 1013.1767, gradientNorm = 0.273489
# Iteration number 58, -f(x) = 1013.1859, gradientNorm = 0.134642
# Iteration number 59, -f(x) = 1013.1932, gradientNorm = 0.214135
# Iteration number 60, -f(x) = 1013.1988, gradientNorm = 0.105094
# Iteration number 61, -f(x) = 1013.2032, gradientNorm = 0.167467
# Iteration number 62, -f(x) = 1013.2067, gradientNorm = 0.081995
# Iteration number 63, -f(x) = 1013.2094, gradientNorm = 0.130856
# Iteration number 64, -f(x) = 1013.2115, gradientNorm = 0.063953
# Iteration number 65, -f(x) = 1013.2131, gradientNorm = 0.102183
# Iteration number 66, -f(x) = 1013.2144, gradientNorm = 0.049871
# Iteration number 67, -f(x) = 1013.2154, gradientNorm = 0.079754
# Iteration number 68, -f(x) = 1013.2162, gradientNorm = 0.038883
# Iteration number 69, -f(x) = 1013.2168, gradientNorm = 0.062226
# Iteration number 70, -f(x) = 1013.2173, gradientNorm = 0.030313
# Iteration number 71, -f(x) = 1013.2176, gradientNorm = 0.048537
# Iteration number 72, -f(x) = 1013.2179, gradientNorm = 0.023630
# Iteration number 73, -f(x) = 1013.2181, gradientNorm = 0.037852
# Iteration number 74, -f(x) = 1013.2183, gradientNorm = 0.018420
# Iteration number 75, -f(x) = 1013.2185, gradientNorm = 0.029515
# Iteration number 76, -f(x) = 1013.2186, gradientNorm = 0.014357
# Iteration number 77, -f(x) = 1013.2186, gradientNorm = 0.023011
# Iteration number 78, -f(x) = 1013.2187, gradientNorm = 0.011191
# Iteration number 79, -f(x) = 1013.2188, gradientNorm = 0.017939
# Iteration number 80, -f(x) = 1013.2188, gradientNorm = 0.008723
# Iteration number 81, -f(x) = 1013.2188, gradientNorm = 0.013985
# Iteration number 82, -f(x) = 1013.2189, gradientNorm = 0.006799
# Iteration number 83, -f(x) = 1013.2189, gradientNorm = 0.010901
# Iteration number 84, -f(x) = 1013.2189, gradientNorm = 0.005299
# Iteration number 85, -f(x) = 1013.2189, gradientNorm = 0.008497
# Iteration number 86, -f(x) = 1013.2189, gradientNorm = 0.004130
# Iteration number 87, -f(x) = 1013.2189, gradientNorm = 0.006623
# Iteration number 88, -f(x) = 1013.2189, gradientNorm = 0.003219
# Iteration number 89, -f(x) = 1013.2189, gradientNorm = 0.005163
# Iteration number 90, -f(x) = 1013.2189, gradientNorm = 0.002509
# Iteration number 91, -f(x) = 1013.2189, gradientNorm = 0.004024
# Iteration number 92, -f(x) = 1013.2189, gradientNorm = 0.001956
# Iteration number 93, -f(x) = 1013.2189, gradientNorm = 0.003136
# Iteration number 94, -f(x) = 1013.2189, gradientNorm = 0.001524
# Iteration number 95, -f(x) = 1013.2189, gradientNorm = 0.002445
# Iteration number 96, -f(x) = 1013.2189, gradientNorm = 0.001188
# Iteration number 97, -f(x) = 1013.2189, gradientNorm = 0.001905
# Iteration number 98, -f(x) = 1013.2189, gradientNorm = 0.000926
# Iteration number 99, -f(x) = 1013.2189, gradientNorm = 0.001485
# Iteration number 100, -f(x) = 1013.2189, gradientNorm = 0.000722
# Iteration number 101, -f(x) = 1013.2189, gradientNorm = 0.001158
# Iteration number 102, -f(x) = 1013.2189, gradientNorm = 0.000563
# Iteration number 103, -f(x) = 1013.2189, gradientNorm = 0.000902
# Iteration number 104, -f(x) = 1013.2189, gradientNorm = 0.000438
# Iteration number 105, -f(x) = 1013.2189, gradientNorm = 0.000703
# Iteration number 106, -f(x) = 1013.2189, gradientNorm = 0.000342
# Iteration number 107, -f(x) = 1013.2189, gradientNorm = 0.000548
# Iteration number 108, -f(x) = 1013.2189, gradientNorm = 0.000266
# Iteration number 109, -f(x) = 1013.2189, gradientNorm = 0.000427
# Iteration number 110, -f(x) = 1013.2189, gradientNorm = 0.000208
# Iteration number 111, -f(x) = 1013.2189, gradientNorm = 0.000333
# Iteration number 112, -f(x) = 1013.2189, gradientNorm = 0.000162
# Iteration number 113, -f(x) = 1013.2189, gradientNorm = 0.000260
# Iteration number 114, -f(x) = 1013.2189, gradientNorm = 0.000126
# Iteration number 115, -f(x) = 1013.2189, gradientNorm = 0.000202
# Iteration number 116, -f(x) = 1013.2189, gradientNorm = 0.000098
# Iteration number 117, -f(x) = 1013.2189, gradientNorm = 0.000158
# Iteration number 118, -f(x) = 1013.2189, gradientNorm = 0.000077
# Iteration number 119, -f(x) = 1013.2189, gradientNorm = 0.000123
# Iteration number 120, -f(x) = 1013.2189, gradientNorm = 0.000060
# Iteration number 121, -f(x) = 1013.2189, gradientNorm = 0.000096
# Iteration number 122, -f(x) = 1013.2189, gradientNorm = 0.000047
# Iteration number 123, -f(x) = 1013.2189, gradientNorm = 0.000075
# Iteration number 124, -f(x) = 1013.2189, gradientNorm = 0.000036
# Iteration number 125, -f(x) = 1013.2189, gradientNorm = 0.000058
# Iteration number 126, -f(x) = 1013.2189, gradientNorm = 0.000028
# Iteration number 127, -f(x) = 1013.2189, gradientNorm = 0.000045
# Iteration number 128, -f(x) = 1013.2189, gradientNorm = 0.000022
# Iteration number 129, -f(x) = 1013.2189, gradientNorm = 0.000035
# Iteration number 130, -f(x) = 1013.2189, gradientNorm = 0.000017
# Iteration number 131, -f(x) = 1013.2189, gradientNorm = 0.000028
# Iteration number 132, -f(x) = 1013.2189, gradientNorm = 0.000013
# Iteration number 133, -f(x) = 1013.2189, gradientNorm = 0.000021
# Iteration number 134, -f(x) = 1013.2189, gradientNorm = 0.000010
# Iteration number 135, -f(x) = 1013.2189, gradientNorm = 0.000017
# Iteration number 136, -f(x) = 1013.2189, gradientNorm = 0.000008

# %%
norm = la.norm(M1, ord=2) ** 2

# %%
# Norm and errors SGD
normsCG = np.array(normsCG)
gradientsCG.insert(0,np.array(gradientCG))
size1 = normsCG.size

# %%
normvec = np.ones(size1) * norm
errorsCG.insert(0, (abs(normsCG - normvec) / abs(normvec)))

# %%
errorsCG[-1][-1]
# Out:
# 1.1960906391829738e-13

# %%
make_plot(gradientsCG, errorsCG,type='M1', experiment_name='exp1-M1')

# %% [raw]
# %%timeit -r 100 -n 10
# # Optimizer SGD
# f = nf.normFunction(M1)
# optimizerCG = CG.conjugateGradient(f, 1e-5, 500, method='HS', x=initial_vector, verbose = False)
# gradientCG, normsCG = optimizerCG.ConjugateGradient()

# %% [raw]
# from scipy.optimize import minimize

# %% [raw]
# %%timeit -r 100 -n 10
# res = minimize(f.func_, initial_vector, method='CG', tol=1e-5)
# value = -res.fun

# %% [markdown]
# # Experiments on Matrix M2

# %%
errorsCG = []
gradientsCG = []

# %%
f = nf.normFunction(M2)

# %%
initial_vector = f.init_x()

# %%
optimizerCG = CG.conjugateGradient(f, 1e-5, 500, method='HS', x=initial_vector, verbose = True)
gradientCG, normsCG = optimizerCG.ConjugateGradient()
# Out:
# Iteration number 1, -f(x) = 2076.1150, gradientNorm = 137.739432
# Iteration number 2, -f(x) = 2351.8166, gradientNorm = 66.912662
# Iteration number 3, -f(x) = 2462.3840, gradientNorm = 33.600874
# Iteration number 4, -f(x) = 2521.2912, gradientNorm = 27.632861
# Iteration number 5, -f(x) = 2553.4049, gradientNorm = 19.307358
# Iteration number 6, -f(x) = 2570.9505, gradientNorm = 15.745098
# Iteration number 7, -f(x) = 2581.3552, gradientNorm = 11.199056
# Iteration number 8, -f(x) = 2586.7751, gradientNorm = 8.825299
# Iteration number 9, -f(x) = 2590.1716, gradientNorm = 7.040435
# Iteration number 10, -f(x) = 2592.2842, gradientNorm = 5.834938
# Iteration number 11, -f(x) = 2593.8597, gradientNorm = 5.369146
# Iteration number 12, -f(x) = 2595.1224, gradientNorm = 4.896985
# Iteration number 13, -f(x) = 2596.3013, gradientNorm = 5.090682
# Iteration number 14, -f(x) = 2597.4578, gradientNorm = 4.915596
# Iteration number 15, -f(x) = 2598.6868, gradientNorm = 5.414861
# Iteration number 16, -f(x) = 2599.9948, gradientNorm = 5.276163
# Iteration number 17, -f(x) = 2601.4361, gradientNorm = 5.929722
# Iteration number 18, -f(x) = 2602.9917, gradientNorm = 5.711472
# Iteration number 19, -f(x) = 2604.7020, gradientNorm = 6.458132
# Iteration number 20, -f(x) = 2606.5270, gradientNorm = 6.100239
# Iteration number 21, -f(x) = 2608.5001, gradientNorm = 6.902498
# Iteration number 22, -f(x) = 2610.5598, gradientNorm = 6.368127
# Iteration number 23, -f(x) = 2612.7342, gradientNorm = 7.193039
# Iteration number 24, -f(x) = 2614.9422, gradientNorm = 6.465669
# Iteration number 25, -f(x) = 2617.2093, gradientNorm = 7.283527
# Iteration number 26, -f(x) = 2619.4428, gradientNorm = 6.370762
# Iteration number 27, -f(x) = 2621.6696, gradientNorm = 7.158334
# Iteration number 28, -f(x) = 2623.7975, gradientNorm = 6.092308
# Iteration number 29, -f(x) = 2625.8582, gradientNorm = 6.834931
# Iteration number 30, -f(x) = 2627.7716, gradientNorm = 5.665977
# Iteration number 31, -f(x) = 2629.5754, gradientNorm = 6.356702
# Iteration number 32, -f(x) = 2631.2085, gradientNorm = 5.142387
# Iteration number 33, -f(x) = 2632.7118, gradientNorm = 5.779212
# Iteration number 34, -f(x) = 2634.0447, gradientNorm = 4.573414
# Iteration number 35, -f(x) = 2635.2475, gradientNorm = 5.156562
# Iteration number 36, -f(x) = 2636.2964, gradientNorm = 4.002271
# Iteration number 37, -f(x) = 2637.2276, gradientNorm = 4.532643
# Iteration number 38, -f(x) = 2638.0295, gradientNorm = 3.459339
# Iteration number 39, -f(x) = 2638.7324, gradientNorm = 3.938084
# Iteration number 40, -f(x) = 2639.3321, gradientNorm = 2.962558
# Iteration number 41, -f(x) = 2639.8524, gradientNorm = 3.391195
# Iteration number 42, -f(x) = 2640.2935, gradientNorm = 2.520071
# Iteration number 43, -f(x) = 2640.6732, gradientNorm = 2.900683
# Iteration number 44, -f(x) = 2640.9936, gradientNorm = 2.133344
# Iteration number 45, -f(x) = 2641.2678, gradientNorm = 2.468640
# Iteration number 46, -f(x) = 2641.4985, gradientNorm = 1.799820
# Iteration number 47, -f(x) = 2641.6950, gradientNorm = 2.093050
# Iteration number 48, -f(x) = 2641.8599, gradientNorm = 1.514844
# Iteration number 49, -f(x) = 2642.0000, gradientNorm = 1.769628
# Iteration number 50, -f(x) = 2642.1174, gradientNorm = 1.272924
# Iteration number 51, -f(x) = 2642.2167, gradientNorm = 1.493056
# Iteration number 52, -f(x) = 2642.3000, gradientNorm = 1.068473
# Iteration number 53, -f(x) = 2642.3703, gradientNorm = 1.257748
# Iteration number 54, -f(x) = 2642.4292, gradientNorm = 0.896218
# Iteration number 55, -f(x) = 2642.4789, gradientNorm = 1.058296
# Iteration number 56, -f(x) = 2642.5205, gradientNorm = 0.751393
# Iteration number 57, -f(x) = 2642.5555, gradientNorm = 0.889704
# Iteration number 58, -f(x) = 2642.5848, gradientNorm = 0.629801
# Iteration number 59, -f(x) = 2642.6095, gradientNorm = 0.747489
# Iteration number 60, -f(x) = 2642.6302, gradientNorm = 0.527808
# Iteration number 61, -f(x) = 2642.6475, gradientNorm = 0.627708
# Iteration number 62, -f(x) = 2642.6621, gradientNorm = 0.442306
# Iteration number 63, -f(x) = 2642.6743, gradientNorm = 0.526936
# Iteration number 64, -f(x) = 2642.6845, gradientNorm = 0.370654
# Iteration number 65, -f(x) = 2642.6931, gradientNorm = 0.442229
# Iteration number 66, -f(x) = 2642.7004, gradientNorm = 0.310619
# Iteration number 67, -f(x) = 2642.7064, gradientNorm = 0.371071
# Iteration number 68, -f(x) = 2642.7115, gradientNorm = 0.260324
# Iteration number 69, -f(x) = 2642.7157, gradientNorm = 0.311322
# Iteration number 70, -f(x) = 2642.7193, gradientNorm = 0.218188
# Iteration number 71, -f(x) = 2642.7223, gradientNorm = 0.261171
# Iteration number 72, -f(x) = 2642.7248, gradientNorm = 0.182887
# Iteration number 73, -f(x) = 2642.7269, gradientNorm = 0.219086
# Iteration number 74, -f(x) = 2642.7286, gradientNorm = 0.153311
# Iteration number 75, -f(x) = 2642.7301, gradientNorm = 0.183777
# Iteration number 76, -f(x) = 2642.7314, gradientNorm = 0.128528
# Iteration number 77, -f(x) = 2642.7324, gradientNorm = 0.154156
# Iteration number 78, -f(x) = 2642.7333, gradientNorm = 0.107761
# Iteration number 79, -f(x) = 2642.7340, gradientNorm = 0.129309
# Iteration number 80, -f(x) = 2642.7346, gradientNorm = 0.090356
# Iteration number 81, -f(x) = 2642.7351, gradientNorm = 0.108468
# Iteration number 82, -f(x) = 2642.7356, gradientNorm = 0.075768
# Iteration number 83, -f(x) = 2642.7359, gradientNorm = 0.090988
# Iteration number 84, -f(x) = 2642.7362, gradientNorm = 0.063541
# Iteration number 85, -f(x) = 2642.7365, gradientNorm = 0.076326
# Iteration number 86, -f(x) = 2642.7367, gradientNorm = 0.053290
# Iteration number 87, -f(x) = 2642.7369, gradientNorm = 0.064029
# Iteration number 88, -f(x) = 2642.7370, gradientNorm = 0.044696
# Iteration number 89, -f(x) = 2642.7372, gradientNorm = 0.053715
# Iteration number 90, -f(x) = 2642.7373, gradientNorm = 0.037490
# Iteration number 91, -f(x) = 2642.7374, gradientNorm = 0.045063
# Iteration number 92, -f(x) = 2642.7374, gradientNorm = 0.031448
# Iteration number 93, -f(x) = 2642.7375, gradientNorm = 0.037806
# Iteration number 94, -f(x) = 2642.7375, gradientNorm = 0.026381
# Iteration number 95, -f(x) = 2642.7376, gradientNorm = 0.031719
# Iteration number 96, -f(x) = 2642.7376, gradientNorm = 0.022132
# Iteration number 97, -f(x) = 2642.7377, gradientNorm = 0.026613
# Iteration number 98, -f(x) = 2642.7377, gradientNorm = 0.018568
# Iteration number 99, -f(x) = 2642.7377, gradientNorm = 0.022329
# Iteration number 100, -f(x) = 2642.7377, gradientNorm = 0.015578
# Iteration number 101, -f(x) = 2642.7377, gradientNorm = 0.018736
# Iteration number 102, -f(x) = 2642.7377, gradientNorm = 0.013071
# Iteration number 103, -f(x) = 2642.7378, gradientNorm = 0.015721
# Iteration number 104, -f(x) = 2642.7378, gradientNorm = 0.010967
# Iteration number 105, -f(x) = 2642.7378, gradientNorm = 0.013192
# Iteration number 106, -f(x) = 2642.7378, gradientNorm = 0.009202
# Iteration number 107, -f(x) = 2642.7378, gradientNorm = 0.011070
# Iteration number 108, -f(x) = 2642.7378, gradientNorm = 0.007722
# Iteration number 109, -f(x) = 2642.7378, gradientNorm = 0.009290
# Iteration number 110, -f(x) = 2642.7378, gradientNorm = 0.006480
# Iteration number 111, -f(x) = 2642.7378, gradientNorm = 0.007796
# Iteration number 112, -f(x) = 2642.7378, gradientNorm = 0.005438
# Iteration number 113, -f(x) = 2642.7378, gradientNorm = 0.006542
# Iteration number 114, -f(x) = 2642.7378, gradientNorm = 0.004563
# Iteration number 115, -f(x) = 2642.7378, gradientNorm = 0.005490
# Iteration number 116, -f(x) = 2642.7378, gradientNorm = 0.003830
# Iteration number 117, -f(x) = 2642.7378, gradientNorm = 0.004608
# Iteration number 118, -f(x) = 2642.7378, gradientNorm = 0.003214
# Iteration number 119, -f(x) = 2642.7378, gradientNorm = 0.003867
# Iteration number 120, -f(x) = 2642.7378, gradientNorm = 0.002697
# Iteration number 121, -f(x) = 2642.7378, gradientNorm = 0.003246
# Iteration number 122, -f(x) = 2642.7378, gradientNorm = 0.002264
# Iteration number 123, -f(x) = 2642.7378, gradientNorm = 0.002724
# Iteration number 124, -f(x) = 2642.7378, gradientNorm = 0.001900
# Iteration number 125, -f(x) = 2642.7378, gradientNorm = 0.002286
# Iteration number 126, -f(x) = 2642.7378, gradientNorm = 0.001595
# Iteration number 127, -f(x) = 2642.7378, gradientNorm = 0.001919
# Iteration number 128, -f(x) = 2642.7378, gradientNorm = 0.001338
# Iteration number 129, -f(x) = 2642.7378, gradientNorm = 0.001611
# Iteration number 130, -f(x) = 2642.7378, gradientNorm = 0.001123
# Iteration number 131, -f(x) = 2642.7378, gradientNorm = 0.001352
# Iteration number 132, -f(x) = 2642.7378, gradientNorm = 0.000943
# Iteration number 133, -f(x) = 2642.7378, gradientNorm = 0.001135
# Iteration number 134, -f(x) = 2642.7378, gradientNorm = 0.000791
# Iteration number 135, -f(x) = 2642.7378, gradientNorm = 0.000952
# Iteration number 136, -f(x) = 2642.7378, gradientNorm = 0.000664
# Iteration number 137, -f(x) = 2642.7378, gradientNorm = 0.000799
# Iteration number 138, -f(x) = 2642.7378, gradientNorm = 0.000558
# Iteration number 139, -f(x) = 2642.7378, gradientNorm = 0.000671
# Iteration number 140, -f(x) = 2642.7378, gradientNorm = 0.000468
# Iteration number 141, -f(x) = 2642.7378, gradientNorm = 0.000563
# Iteration number 142, -f(x) = 2642.7378, gradientNorm = 0.000393
# Iteration number 143, -f(x) = 2642.7378, gradientNorm = 0.000473
# Iteration number 144, -f(x) = 2642.7378, gradientNorm = 0.000330
# Iteration number 145, -f(x) = 2642.7378, gradientNorm = 0.000397
# Iteration number 146, -f(x) = 2642.7378, gradientNorm = 0.000277
# Iteration number 147, -f(x) = 2642.7378, gradientNorm = 0.000333
# Iteration number 148, -f(x) = 2642.7378, gradientNorm = 0.000232
# Iteration number 149, -f(x) = 2642.7378, gradientNorm = 0.000280
# Iteration number 150, -f(x) = 2642.7378, gradientNorm = 0.000195
# Iteration number 151, -f(x) = 2642.7378, gradientNorm = 0.000235
# Iteration number 152, -f(x) = 2642.7378, gradientNorm = 0.000164
# Iteration number 153, -f(x) = 2642.7378, gradientNorm = 0.000197
# Iteration number 154, -f(x) = 2642.7378, gradientNorm = 0.000137
# Iteration number 155, -f(x) = 2642.7378, gradientNorm = 0.000165
# Iteration number 156, -f(x) = 2642.7378, gradientNorm = 0.000115
# Iteration number 157, -f(x) = 2642.7378, gradientNorm = 0.000139
# Iteration number 158, -f(x) = 2642.7378, gradientNorm = 0.000097
# Iteration number 159, -f(x) = 2642.7378, gradientNorm = 0.000117
# Iteration number 160, -f(x) = 2642.7378, gradientNorm = 0.000081
# Iteration number 161, -f(x) = 2642.7378, gradientNorm = 0.000098
# Iteration number 162, -f(x) = 2642.7378, gradientNorm = 0.000068
# Iteration number 163, -f(x) = 2642.7378, gradientNorm = 0.000082
# Iteration number 164, -f(x) = 2642.7378, gradientNorm = 0.000057
# Iteration number 165, -f(x) = 2642.7378, gradientNorm = 0.000069
# Iteration number 166, -f(x) = 2642.7378, gradientNorm = 0.000048
# Iteration number 167, -f(x) = 2642.7378, gradientNorm = 0.000058
# Iteration number 168, -f(x) = 2642.7378, gradientNorm = 0.000040
# Iteration number 169, -f(x) = 2642.7378, gradientNorm = 0.000049
# Iteration number 170, -f(x) = 2642.7378, gradientNorm = 0.000034
# Iteration number 171, -f(x) = 2642.7378, gradientNorm = 0.000041
# Iteration number 172, -f(x) = 2642.7378, gradientNorm = 0.000028
# Iteration number 173, -f(x) = 2642.7378, gradientNorm = 0.000034
# Iteration number 174, -f(x) = 2642.7378, gradientNorm = 0.000024
# Iteration number 175, -f(x) = 2642.7378, gradientNorm = 0.000029
# Iteration number 176, -f(x) = 2642.7378, gradientNorm = 0.000020
# Iteration number 177, -f(x) = 2642.7378, gradientNorm = 0.000024
# Iteration number 178, -f(x) = 2642.7378, gradientNorm = 0.000017
# Iteration number 179, -f(x) = 2642.7378, gradientNorm = 0.000020
# Iteration number 180, -f(x) = 2642.7378, gradientNorm = 0.000014
# Iteration number 181, -f(x) = 2642.7378, gradientNorm = 0.000017
# Iteration number 182, -f(x) = 2642.7378, gradientNorm = 0.000012
# Iteration number 183, -f(x) = 2642.7378, gradientNorm = 0.000014
# Iteration number 184, -f(x) = 2642.7378, gradientNorm = 0.000010

# %%
norm = la.norm(M2, ord=2) ** 2

# %%
# Norm and errors SGD
normsCG = np.array(normsCG)
gradientsCG.insert(0,np.array(gradientCG))
size1 = normsCG.size

# %%
normvec = np.ones(size1) * norm
errorsCG.insert(0, (abs(normsCG - normvec) / abs(normvec)))

# %%
errorsCG[-1][-1]
# Out:
# 1.3938021096674776e-14

# %%
make_plot(gradientsCG, errorsCG,type='M2', experiment_name='exp1-M2')

# %% [raw]
# %%timeit -r 100 -n 10
# # Optimizer SGD
# f = nf.normFunction(M2)
# optimizerCG = CG.conjugateGradient(f, 1e-5, 500, method='HS', x=initial_vector, verbose = False)
# gradientCG, normsCG = optimizerCG.ConjugateGradient()

# %% [raw]
# from scipy.optimize import minimize

# %% [raw]
# %%timeit -r 100 -n 10
# res = minimize(f.func_, initial_vector, method='CG', tol=1e-5)
# value = -res.fun

# %% [markdown]
# # Experiments on Matrix M3

# %%
errorsCG = []
gradientsCG = []

# %%
f = nf.normFunction(M3)

# %%
initial_vector = f.init_x()

# %%
optimizerCG = CG.conjugateGradient(f, 1e-5, 500, method='HS', x=initial_vector, verbose = True)
gradientCG, normsCG = optimizerCG.ConjugateGradient()
# Out:
# Iteration number 1, -f(x) = 540.2637, gradientNorm = 35.858083
# Iteration number 2, -f(x) = 602.8864, gradientNorm = 16.548021
# Iteration number 3, -f(x) = 628.2095, gradientNorm = 9.889281
# Iteration number 4, -f(x) = 646.1972, gradientNorm = 8.038850
# Iteration number 5, -f(x) = 656.0721, gradientNorm = 5.844864
# Iteration number 6, -f(x) = 661.6614, gradientNorm = 5.103361
# Iteration number 7, -f(x) = 665.9426, gradientNorm = 4.358005
# Iteration number 8, -f(x) = 668.6877, gradientNorm = 3.584982
# Iteration number 9, -f(x) = 670.9777, gradientNorm = 3.438476
# Iteration number 10, -f(x) = 672.5306, gradientNorm = 2.566411
# Iteration number 11, -f(x) = 673.7617, gradientNorm = 2.617234
# Iteration number 12, -f(x) = 674.6152, gradientNorm = 1.836905
# Iteration number 13, -f(x) = 675.2678, gradientNorm = 1.951193
# Iteration number 14, -f(x) = 675.7301, gradientNorm = 1.328652
# Iteration number 15, -f(x) = 676.0810, gradientNorm = 1.459017
# Iteration number 16, -f(x) = 676.3363, gradientNorm = 0.981787
# Iteration number 17, -f(x) = 676.5322, gradientNorm = 1.110210
# Iteration number 18, -f(x) = 676.6791, gradientNorm = 0.744976
# Iteration number 19, -f(x) = 676.7940, gradientNorm = 0.863838
# Iteration number 20, -f(x) = 676.8827, gradientNorm = 0.579955
# Iteration number 21, -f(x) = 676.9534, gradientNorm = 0.686044
# Iteration number 22, -f(x) = 677.0092, gradientNorm = 0.460996
# Iteration number 23, -f(x) = 677.0543, gradientNorm = 0.553426
# Iteration number 24, -f(x) = 677.0905, gradientNorm = 0.371952
# Iteration number 25, -f(x) = 677.1202, gradientNorm = 0.451172
# Iteration number 26, -f(x) = 677.1442, gradientNorm = 0.303055
# Iteration number 27, -f(x) = 677.1640, gradientNorm = 0.370210
# Iteration number 28, -f(x) = 677.1802, gradientNorm = 0.248408
# Iteration number 29, -f(x) = 677.1935, gradientNorm = 0.304919
# Iteration number 30, -f(x) = 677.2045, gradientNorm = 0.204335
# Iteration number 31, -f(x) = 677.2135, gradientNorm = 0.251655
# Iteration number 32, -f(x) = 677.2210, gradientNorm = 0.168421
# Iteration number 33, -f(x) = 677.2271, gradientNorm = 0.207912
# Iteration number 34, -f(x) = 677.2322, gradientNorm = 0.138974
# Iteration number 35, -f(x) = 677.2364, gradientNorm = 0.171854
# Iteration number 36, -f(x) = 677.2399, gradientNorm = 0.114745
# Iteration number 37, -f(x) = 677.2428, gradientNorm = 0.142075
# Iteration number 38, -f(x) = 677.2451, gradientNorm = 0.094771
# Iteration number 39, -f(x) = 677.2471, gradientNorm = 0.117458
# Iteration number 40, -f(x) = 677.2487, gradientNorm = 0.078286
# Iteration number 41, -f(x) = 677.2500, gradientNorm = 0.097102
# Iteration number 42, -f(x) = 677.2512, gradientNorm = 0.064674
# Iteration number 43, -f(x) = 677.2521, gradientNorm = 0.080267
# Iteration number 44, -f(x) = 677.2528, gradientNorm = 0.053430
# Iteration number 45, -f(x) = 677.2534, gradientNorm = 0.066345
# Iteration number 46, -f(x) = 677.2540, gradientNorm = 0.044142
# Iteration number 47, -f(x) = 677.2544, gradientNorm = 0.054833
# Iteration number 48, -f(x) = 677.2547, gradientNorm = 0.036468
# Iteration number 49, -f(x) = 677.2550, gradientNorm = 0.045316
# Iteration number 50, -f(x) = 677.2553, gradientNorm = 0.030128
# Iteration number 51, -f(x) = 677.2555, gradientNorm = 0.037448
# Iteration number 52, -f(x) = 677.2556, gradientNorm = 0.024891
# Iteration number 53, -f(x) = 677.2558, gradientNorm = 0.030944
# Iteration number 54, -f(x) = 677.2559, gradientNorm = 0.020563
# Iteration number 55, -f(x) = 677.2560, gradientNorm = 0.025569
# Iteration number 56, -f(x) = 677.2561, gradientNorm = 0.016988
# Iteration number 57, -f(x) = 677.2561, gradientNorm = 0.021127
# Iteration number 58, -f(x) = 677.2562, gradientNorm = 0.014035
# Iteration number 59, -f(x) = 677.2562, gradientNorm = 0.017456
# Iteration number 60, -f(x) = 677.2562, gradientNorm = 0.011594
# Iteration number 61, -f(x) = 677.2563, gradientNorm = 0.014422
# Iteration number 62, -f(x) = 677.2563, gradientNorm = 0.009578
# Iteration number 63, -f(x) = 677.2563, gradientNorm = 0.011916
# Iteration number 64, -f(x) = 677.2563, gradientNorm = 0.007913
# Iteration number 65, -f(x) = 677.2564, gradientNorm = 0.009845
# Iteration number 66, -f(x) = 677.2564, gradientNorm = 0.006537
# Iteration number 67, -f(x) = 677.2564, gradientNorm = 0.008133
# Iteration number 68, -f(x) = 677.2564, gradientNorm = 0.005401
# Iteration number 69, -f(x) = 677.2564, gradientNorm = 0.006720
# Iteration number 70, -f(x) = 677.2564, gradientNorm = 0.004462
# Iteration number 71, -f(x) = 677.2564, gradientNorm = 0.005551
# Iteration number 72, -f(x) = 677.2564, gradientNorm = 0.003686
# Iteration number 73, -f(x) = 677.2564, gradientNorm = 0.004586
# Iteration number 74, -f(x) = 677.2564, gradientNorm = 0.003045
# Iteration number 75, -f(x) = 677.2564, gradientNorm = 0.003789
# Iteration number 76, -f(x) = 677.2564, gradientNorm = 0.002515
# Iteration number 77, -f(x) = 677.2564, gradientNorm = 0.003130
# Iteration number 78, -f(x) = 677.2564, gradientNorm = 0.002078
# Iteration number 79, -f(x) = 677.2564, gradientNorm = 0.002586
# Iteration number 80, -f(x) = 677.2564, gradientNorm = 0.001717
# Iteration number 81, -f(x) = 677.2564, gradientNorm = 0.002136
# Iteration number 82, -f(x) = 677.2564, gradientNorm = 0.001418
# Iteration number 83, -f(x) = 677.2564, gradientNorm = 0.001765
# Iteration number 84, -f(x) = 677.2564, gradientNorm = 0.001172
# Iteration number 85, -f(x) = 677.2564, gradientNorm = 0.001458
# Iteration number 86, -f(x) = 677.2564, gradientNorm = 0.000968
# Iteration number 87, -f(x) = 677.2564, gradientNorm = 0.001205
# Iteration number 88, -f(x) = 677.2564, gradientNorm = 0.000800
# Iteration number 89, -f(x) = 677.2564, gradientNorm = 0.000995
# Iteration number 90, -f(x) = 677.2564, gradientNorm = 0.000661
# Iteration number 91, -f(x) = 677.2564, gradientNorm = 0.000822
# Iteration number 92, -f(x) = 677.2564, gradientNorm = 0.000546
# Iteration number 93, -f(x) = 677.2564, gradientNorm = 0.000679
# Iteration number 94, -f(x) = 677.2564, gradientNorm = 0.000451
# Iteration number 95, -f(x) = 677.2564, gradientNorm = 0.000561
# Iteration number 96, -f(x) = 677.2564, gradientNorm = 0.000372
# Iteration number 97, -f(x) = 677.2564, gradientNorm = 0.000464
# Iteration number 98, -f(x) = 677.2564, gradientNorm = 0.000308
# Iteration number 99, -f(x) = 677.2564, gradientNorm = 0.000383
# Iteration number 100, -f(x) = 677.2564, gradientNorm = 0.000254
# Iteration number 101, -f(x) = 677.2564, gradientNorm = 0.000316
# Iteration number 102, -f(x) = 677.2564, gradientNorm = 0.000210
# Iteration number 103, -f(x) = 677.2564, gradientNorm = 0.000261
# Iteration number 104, -f(x) = 677.2564, gradientNorm = 0.000173
# Iteration number 105, -f(x) = 677.2564, gradientNorm = 0.000216
# Iteration number 106, -f(x) = 677.2564, gradientNorm = 0.000143
# Iteration number 107, -f(x) = 677.2564, gradientNorm = 0.000178
# Iteration number 108, -f(x) = 677.2564, gradientNorm = 0.000118
# Iteration number 109, -f(x) = 677.2564, gradientNorm = 0.000147
# Iteration number 110, -f(x) = 677.2564, gradientNorm = 0.000098
# Iteration number 111, -f(x) = 677.2564, gradientNorm = 0.000122
# Iteration number 112, -f(x) = 677.2564, gradientNorm = 0.000081
# Iteration number 113, -f(x) = 677.2564, gradientNorm = 0.000101
# Iteration number 114, -f(x) = 677.2564, gradientNorm = 0.000067
# Iteration number 115, -f(x) = 677.2564, gradientNorm = 0.000083
# Iteration number 116, -f(x) = 677.2564, gradientNorm = 0.000055
# Iteration number 117, -f(x) = 677.2564, gradientNorm = 0.000069
# Iteration number 118, -f(x) = 677.2564, gradientNorm = 0.000046
# Iteration number 119, -f(x) = 677.2564, gradientNorm = 0.000057
# Iteration number 120, -f(x) = 677.2564, gradientNorm = 0.000038
# Iteration number 121, -f(x) = 677.2564, gradientNorm = 0.000047
# Iteration number 122, -f(x) = 677.2564, gradientNorm = 0.000031
# Iteration number 123, -f(x) = 677.2564, gradientNorm = 0.000039
# Iteration number 124, -f(x) = 677.2564, gradientNorm = 0.000026
# Iteration number 125, -f(x) = 677.2564, gradientNorm = 0.000032
# Iteration number 126, -f(x) = 677.2564, gradientNorm = 0.000021
# Iteration number 127, -f(x) = 677.2564, gradientNorm = 0.000026
# Iteration number 128, -f(x) = 677.2564, gradientNorm = 0.000018
# Iteration number 129, -f(x) = 677.2564, gradientNorm = 0.000022
# Iteration number 130, -f(x) = 677.2564, gradientNorm = 0.000014
# Iteration number 131, -f(x) = 677.2564, gradientNorm = 0.000018
# Iteration number 132, -f(x) = 677.2564, gradientNorm = 0.000012
# Iteration number 133, -f(x) = 677.2564, gradientNorm = 0.000015
# Iteration number 134, -f(x) = 677.2564, gradientNorm = 0.000010

# %%
norm = la.norm(M3, ord=2) ** 2

# %%
# Norm and errors SGD
normsCG = np.array(normsCG)
gradientsCG.insert(0,np.array(gradientCG))
size1 = normsCG.size

# %%
normvec = np.ones(size1) * norm
errorsCG.insert(0, (abs(normsCG - normvec) / abs(normvec)))

# %%
errorsCG[-1][-1]
# Out:
# 1.8230009041640778e-13

# %%
make_plot(gradientsCG, errorsCG, type='M3', experiment_name='exp1-M3')

# %% [raw]
# %%timeit -r 100 -n 10
# # Optimizer SGD
# f = nf.normFunction(M3)
# optimizerCG = CG.conjugateGradient(f, 1e-5, 500, method='HS', x=initial_vector, verbose = False)
# gradientCG, normsCG = optimizerCG.ConjugateGradient()

# %% [raw]
# from scipy.optimize import minimize

# %% [raw]
# inimization of scalar function of one or more variables using the conjugate gradient algorithm.
#
# %%timeit -r 100 -n 10
# res = minimize(f.func_, initial_vector, method='CG', tol=1e-5)
# value = -res.fun

# %% [markdown]
# # Experiments on Matrix M4

# %%
errorsCG = []
gradientsCG = []

# %%
f = nf.normFunction(M4)

# %%
initial_vector = f.init_x()

# %%
optimizerCG = CG.conjugateGradient(f, 1e-5, 500, method='HS', x=initial_vector, verbose = True)
gradientCG, normsCG = optimizerCG.ConjugateGradient()
# Out:
# Iteration number 1, -f(x) = 49.7894, gradientNorm = 24.552527
# Iteration number 2, -f(x) = 2128.3436, gradientNorm = 3.456860
# Iteration number 3, -f(x) = 2386.3585, gradientNorm = 1.636645
# Iteration number 4, -f(x) = 2509.8754, gradientNorm = 1.388020
# Iteration number 5, -f(x) = 2577.4455, gradientNorm = 0.854173
# Iteration number 6, -f(x) = 2603.4565, gradientNorm = 0.840983
# Iteration number 7, -f(x) = 2614.1397, gradientNorm = 0.536965
# Iteration number 8, -f(x) = 2621.2573, gradientNorm = 0.573860
# Iteration number 9, -f(x) = 2626.4088, gradientNorm = 0.402251
# Iteration number 10, -f(x) = 2630.5105, gradientNorm = 0.452853
# Iteration number 11, -f(x) = 2633.7161, gradientNorm = 0.318455
# Iteration number 12, -f(x) = 2636.3482, gradientNorm = 0.369371
# Iteration number 13, -f(x) = 2638.4782, gradientNorm = 0.260130
# Iteration number 14, -f(x) = 2640.2660, gradientNorm = 0.308303
# Iteration number 15, -f(x) = 2641.7471, gradientNorm = 0.216930
# Iteration number 16, -f(x) = 2643.0070, gradientNorm = 0.260986
# Iteration number 17, -f(x) = 2644.0660, gradientNorm = 0.183189
# Iteration number 18, -f(x) = 2644.9736, gradientNorm = 0.222733
# Iteration number 19, -f(x) = 2645.7431, gradientNorm = 0.155853
# Iteration number 20, -f(x) = 2646.4052, gradientNorm = 0.190971
# Iteration number 21, -f(x) = 2646.9696, gradientNorm = 0.133198
# Iteration number 22, -f(x) = 2647.4564, gradientNorm = 0.164192
# Iteration number 23, -f(x) = 2647.8728, gradientNorm = 0.114172
# Iteration number 24, -f(x) = 2648.2323, gradientNorm = 0.141423
# Iteration number 25, -f(x) = 2648.5406, gradientNorm = 0.098072
# Iteration number 26, -f(x) = 2648.8072, gradientNorm = 0.121975
# Iteration number 27, -f(x) = 2649.0361, gradientNorm = 0.084386
# Iteration number 28, -f(x) = 2649.2342, gradientNorm = 0.105321
# Iteration number 29, -f(x) = 2649.4047, gradientNorm = 0.072719
# Iteration number 30, -f(x) = 2649.5523, gradientNorm = 0.091038
# Iteration number 31, -f(x) = 2649.6795, gradientNorm = 0.062752
# Iteration number 32, -f(x) = 2649.7898, gradientNorm = 0.078775
# Iteration number 33, -f(x) = 2649.8849, gradientNorm = 0.054225
# Iteration number 34, -f(x) = 2649.9675, gradientNorm = 0.068239
# Iteration number 35, -f(x) = 2650.0388, gradientNorm = 0.046919
# Iteration number 36, -f(x) = 2650.1007, gradientNorm = 0.059177
# Iteration number 37, -f(x) = 2650.1543, gradientNorm = 0.040652
# Iteration number 38, -f(x) = 2650.2009, gradientNorm = 0.051376
# Iteration number 39, -f(x) = 2650.2413, gradientNorm = 0.035269
# Iteration number 40, -f(x) = 2650.2765, gradientNorm = 0.044655
# Iteration number 41, -f(x) = 2650.3070, gradientNorm = 0.030638
# Iteration number 42, -f(x) = 2650.3335, gradientNorm = 0.038859
# Iteration number 43, -f(x) = 2650.3566, gradientNorm = 0.026651
# Iteration number 44, -f(x) = 2650.3767, gradientNorm = 0.033855
# Iteration number 45, -f(x) = 2650.3942, gradientNorm = 0.023213
# Iteration number 46, -f(x) = 2650.4095, gradientNorm = 0.029531
# Iteration number 47, -f(x) = 2650.4228, gradientNorm = 0.020244
# Iteration number 48, -f(x) = 2650.4345, gradientNorm = 0.025789
# Iteration number 49, -f(x) = 2650.4446, gradientNorm = 0.017678
# Iteration number 50, -f(x) = 2650.4535, gradientNorm = 0.022548
# Iteration number 51, -f(x) = 2650.4613, gradientNorm = 0.015456
# Iteration number 52, -f(x) = 2650.4681, gradientNorm = 0.019739
# Iteration number 53, -f(x) = 2650.4740, gradientNorm = 0.013531
# Iteration number 54, -f(x) = 2650.4793, gradientNorm = 0.017299
# Iteration number 55, -f(x) = 2650.4838, gradientNorm = 0.011860
# Iteration number 56, -f(x) = 2650.4878, gradientNorm = 0.015180
# Iteration number 57, -f(x) = 2650.4914, gradientNorm = 0.010409
# Iteration number 58, -f(x) = 2650.4945, gradientNorm = 0.013336
# Iteration number 59, -f(x) = 2650.4972, gradientNorm = 0.009146
# Iteration number 60, -f(x) = 2650.4996, gradientNorm = 0.011730
# Iteration number 61, -f(x) = 2650.5017, gradientNorm = 0.008047
# Iteration number 62, -f(x) = 2650.5035, gradientNorm = 0.010329
# Iteration number 63, -f(x) = 2650.5051, gradientNorm = 0.007088
# Iteration number 64, -f(x) = 2650.5066, gradientNorm = 0.009107
# Iteration number 65, -f(x) = 2650.5078, gradientNorm = 0.006251
# Iteration number 66, -f(x) = 2650.5090, gradientNorm = 0.008038
# Iteration number 67, -f(x) = 2650.5099, gradientNorm = 0.005519
# Iteration number 68, -f(x) = 2650.5108, gradientNorm = 0.007104
# Iteration number 69, -f(x) = 2650.5116, gradientNorm = 0.004879
# Iteration number 70, -f(x) = 2650.5123, gradientNorm = 0.006285
# Iteration number 71, -f(x) = 2650.5129, gradientNorm = 0.004319
# Iteration number 72, -f(x) = 2650.5134, gradientNorm = 0.005568
# Iteration number 73, -f(x) = 2650.5139, gradientNorm = 0.003827
# Iteration number 74, -f(x) = 2650.5143, gradientNorm = 0.004938
# Iteration number 75, -f(x) = 2650.5147, gradientNorm = 0.003395
# Iteration number 76, -f(x) = 2650.5150, gradientNorm = 0.004384
# Iteration number 77, -f(x) = 2650.5153, gradientNorm = 0.003016
# Iteration number 78, -f(x) = 2650.5156, gradientNorm = 0.003897
# Iteration number 79, -f(x) = 2650.5158, gradientNorm = 0.002682
# Iteration number 80, -f(x) = 2650.5160, gradientNorm = 0.003468
# Iteration number 81, -f(x) = 2650.5162, gradientNorm = 0.002387
# Iteration number 82, -f(x) = 2650.5163, gradientNorm = 0.003089
# Iteration number 83, -f(x) = 2650.5165, gradientNorm = 0.002128
# Iteration number 84, -f(x) = 2650.5166, gradientNorm = 0.002755
# Iteration number 85, -f(x) = 2650.5167, gradientNorm = 0.001898
# Iteration number 86, -f(x) = 2650.5168, gradientNorm = 0.002460
# Iteration number 87, -f(x) = 2650.5169, gradientNorm = 0.001696
# Iteration number 88, -f(x) = 2650.5170, gradientNorm = 0.002199
# Iteration number 89, -f(x) = 2650.5171, gradientNorm = 0.001516
# Iteration number 90, -f(x) = 2650.5172, gradientNorm = 0.001967
# Iteration number 91, -f(x) = 2650.5172, gradientNorm = 0.001357
# Iteration number 92, -f(x) = 2650.5173, gradientNorm = 0.001761
# Iteration number 93, -f(x) = 2650.5173, gradientNorm = 0.001215
# Iteration number 94, -f(x) = 2650.5174, gradientNorm = 0.001579
# Iteration number 95, -f(x) = 2650.5174, gradientNorm = 0.001090
# Iteration number 96, -f(x) = 2650.5174, gradientNorm = 0.001417
# Iteration number 97, -f(x) = 2650.5175, gradientNorm = 0.000978
# Iteration number 98, -f(x) = 2650.5175, gradientNorm = 0.001272
# Iteration number 99, -f(x) = 2650.5175, gradientNorm = 0.000879
# Iteration number 100, -f(x) = 2650.5175, gradientNorm = 0.001143
# Iteration number 101, -f(x) = 2650.5176, gradientNorm = 0.000790
# Iteration number 102, -f(x) = 2650.5176, gradientNorm = 0.001028
# Iteration number 103, -f(x) = 2650.5176, gradientNorm = 0.000711
# Iteration number 104, -f(x) = 2650.5176, gradientNorm = 0.000926
# Iteration number 105, -f(x) = 2650.5176, gradientNorm = 0.000640
# Iteration number 106, -f(x) = 2650.5176, gradientNorm = 0.000834
# Iteration number 107, -f(x) = 2650.5176, gradientNorm = 0.000577
# Iteration number 108, -f(x) = 2650.5177, gradientNorm = 0.000752
# Iteration number 109, -f(x) = 2650.5177, gradientNorm = 0.000520
# Iteration number 110, -f(x) = 2650.5177, gradientNorm = 0.000678
# Iteration number 111, -f(x) = 2650.5177, gradientNorm = 0.000469
# Iteration number 112, -f(x) = 2650.5177, gradientNorm = 0.000612
# Iteration number 113, -f(x) = 2650.5177, gradientNorm = 0.000424
# Iteration number 114, -f(x) = 2650.5177, gradientNorm = 0.000553
# Iteration number 115, -f(x) = 2650.5177, gradientNorm = 0.000383
# Iteration number 116, -f(x) = 2650.5177, gradientNorm = 0.000499
# Iteration number 117, -f(x) = 2650.5177, gradientNorm = 0.000346
# Iteration number 118, -f(x) = 2650.5177, gradientNorm = 0.000452
# Iteration number 119, -f(x) = 2650.5177, gradientNorm = 0.000313
# Iteration number 120, -f(x) = 2650.5177, gradientNorm = 0.000408
# Iteration number 121, -f(x) = 2650.5177, gradientNorm = 0.000283
# Iteration number 122, -f(x) = 2650.5177, gradientNorm = 0.000370
# Iteration number 123, -f(x) = 2650.5177, gradientNorm = 0.000256
# Iteration number 124, -f(x) = 2650.5177, gradientNorm = 0.000335
# Iteration number 125, -f(x) = 2650.5177, gradientNorm = 0.000232
# Iteration number 126, -f(x) = 2650.5177, gradientNorm = 0.000303
# Iteration number 127, -f(x) = 2650.5177, gradientNorm = 0.000210
# Iteration number 128, -f(x) = 2650.5177, gradientNorm = 0.000275
# Iteration number 129, -f(x) = 2650.5177, gradientNorm = 0.000190
# Iteration number 130, -f(x) = 2650.5177, gradientNorm = 0.000249
# Iteration number 131, -f(x) = 2650.5177, gradientNorm = 0.000173
# Iteration number 132, -f(x) = 2650.5177, gradientNorm = 0.000226
# Iteration number 133, -f(x) = 2650.5177, gradientNorm = 0.000156
# Iteration number 134, -f(x) = 2650.5177, gradientNorm = 0.000205
# Iteration number 135, -f(x) = 2650.5177, gradientNorm = 0.000142
# Iteration number 136, -f(x) = 2650.5177, gradientNorm = 0.000186
# Iteration number 137, -f(x) = 2650.5177, gradientNorm = 0.000129
# Iteration number 138, -f(x) = 2650.5177, gradientNorm = 0.000168
# Iteration number 139, -f(x) = 2650.5177, gradientNorm = 0.000117
# Iteration number 140, -f(x) = 2650.5177, gradientNorm = 0.000153
# Iteration number 141, -f(x) = 2650.5177, gradientNorm = 0.000106
# Iteration number 142, -f(x) = 2650.5177, gradientNorm = 0.000139
# Iteration number 143, -f(x) = 2650.5177, gradientNorm = 0.000096
# Iteration number 144, -f(x) = 2650.5177, gradientNorm = 0.000126
# Iteration number 145, -f(x) = 2650.5177, gradientNorm = 0.000087
# Iteration number 146, -f(x) = 2650.5177, gradientNorm = 0.000114
# Iteration number 147, -f(x) = 2650.5177, gradientNorm = 0.000079
# Iteration number 148, -f(x) = 2650.5177, gradientNorm = 0.000104
# Iteration number 149, -f(x) = 2650.5177, gradientNorm = 0.000072
# Iteration number 150, -f(x) = 2650.5177, gradientNorm = 0.000094
# Iteration number 151, -f(x) = 2650.5177, gradientNorm = 0.000065
# Iteration number 152, -f(x) = 2650.5177, gradientNorm = 0.000086
# Iteration number 153, -f(x) = 2650.5177, gradientNorm = 0.000059
# Iteration number 154, -f(x) = 2650.5177, gradientNorm = 0.000078
# Iteration number 155, -f(x) = 2650.5177, gradientNorm = 0.000054
# Iteration number 156, -f(x) = 2650.5177, gradientNorm = 0.000071
# Iteration number 157, -f(x) = 2650.5177, gradientNorm = 0.000049
# Iteration number 158, -f(x) = 2650.5177, gradientNorm = 0.000064
# Iteration number 159, -f(x) = 2650.5177, gradientNorm = 0.000045
# Iteration number 160, -f(x) = 2650.5177, gradientNorm = 0.000058
# Iteration number 161, -f(x) = 2650.5177, gradientNorm = 0.000041
# Iteration number 162, -f(x) = 2650.5177, gradientNorm = 0.000053
# Iteration number 163, -f(x) = 2650.5177, gradientNorm = 0.000037
# Iteration number 164, -f(x) = 2650.5177, gradientNorm = 0.000048
# Iteration number 165, -f(x) = 2650.5177, gradientNorm = 0.000034
# Iteration number 166, -f(x) = 2650.5177, gradientNorm = 0.000044
# Iteration number 167, -f(x) = 2650.5177, gradientNorm = 0.000030
# Iteration number 168, -f(x) = 2650.5177, gradientNorm = 0.000040
# Iteration number 169, -f(x) = 2650.5177, gradientNorm = 0.000028
# Iteration number 170, -f(x) = 2650.5177, gradientNorm = 0.000036
# Iteration number 171, -f(x) = 2650.5177, gradientNorm = 0.000025
# Iteration number 172, -f(x) = 2650.5177, gradientNorm = 0.000033
# Iteration number 173, -f(x) = 2650.5177, gradientNorm = 0.000023
# Iteration number 174, -f(x) = 2650.5177, gradientNorm = 0.000030
# Iteration number 175, -f(x) = 2650.5177, gradientNorm = 0.000021
# Iteration number 176, -f(x) = 2650.5177, gradientNorm = 0.000027
# Iteration number 177, -f(x) = 2650.5177, gradientNorm = 0.000019
# Iteration number 178, -f(x) = 2650.5177, gradientNorm = 0.000025
# Iteration number 179, -f(x) = 2650.5177, gradientNorm = 0.000017
# Iteration number 180, -f(x) = 2650.5177, gradientNorm = 0.000023
# Iteration number 181, -f(x) = 2650.5177, gradientNorm = 0.000016
# Iteration number 182, -f(x) = 2650.5177, gradientNorm = 0.000021
# Iteration number 183, -f(x) = 2650.5177, gradientNorm = 0.000014
# Iteration number 184, -f(x) = 2650.5177, gradientNorm = 0.000019
# Iteration number 185, -f(x) = 2650.5177, gradientNorm = 0.000013
# Iteration number 186, -f(x) = 2650.5177, gradientNorm = 0.000017
# Iteration number 187, -f(x) = 2650.5177, gradientNorm = 0.000012
# Iteration number 188, -f(x) = 2650.5177, gradientNorm = 0.000015
# Iteration number 189, -f(x) = 2650.5177, gradientNorm = 0.000011
# Iteration number 190, -f(x) = 2650.5177, gradientNorm = 0.000014
# Iteration number 191, -f(x) = 2650.5177, gradientNorm = 0.000010

# %%
norm = la.norm(M4, ord=2) ** 2

# %%
# Norm and errors SGD
normsCG = np.array(normsCG)
gradientsCG.insert(0,np.array(gradientCG))
size1 = normsCG.size

# %%
normvec = np.ones(size1) * norm
errorsCG.insert(0, (abs(normsCG - normvec) / abs(normvec)))

# %%
errorsCG[-1][-1]
# Out:
# 1.1499257653499957e-11

# %%
make_plot(gradientsCG, errorsCG, type='M4', experiment_name='exp1-M4')

# %% [raw]
# %%timeit -r 100 -n 10
# # Optimizer SGD
# f = nf.normFunction(M4)
# optimizerCG = CG.conjugateGradient(f, 1e-5, 500, method='HS', x=initial_vector, verbose = False)
# gradientCG, normsCG = optimizerCG.ConjugateGradient()

# %% [raw]
# from scipy.optimize import minimize

# %% [raw]
# %%timeit -r 100 -n 10
# res = minimize(f.func_, initial_vector, method='CG', tol=1e-5)
# value = -res.fun

# %% [markdown]
# # Experiments on Matrix M5

# %%
errorsCG = []
gradientsCG = []

# %%
f = nf.normFunction(M5)

# %%
initial_vector = f.init_x()

# %%
optimizerCG = CG.conjugateGradient(f, 1e-5, 500, method='HS', x=initial_vector, verbose = True)
gradientCG, normsCG = optimizerCG.ConjugateGradient()
# Out:
# Iteration number 1, -f(x) = 923.1855, gradientNorm = 709.644818
# Iteration number 2, -f(x) = 62485.1363, gradientNorm = 267.021054
# Iteration number 3, -f(x) = 80400.2345, gradientNorm = 89.856389
# Iteration number 4, -f(x) = 86014.2796, gradientNorm = 64.991358
# Iteration number 5, -f(x) = 88846.8877, gradientNorm = 48.478404
# Iteration number 6, -f(x) = 90641.4911, gradientNorm = 42.965822
# Iteration number 7, -f(x) = 91949.3311, gradientNorm = 34.782737
# Iteration number 8, -f(x) = 92858.9632, gradientNorm = 30.554071
# Iteration number 9, -f(x) = 93541.4519, gradientNorm = 26.117374
# Iteration number 10, -f(x) = 94055.2105, gradientNorm = 23.557217
# Iteration number 11, -f(x) = 94473.5376, gradientNorm = 21.393987
# Iteration number 12, -f(x) = 94820.5852, gradientNorm = 19.915029
# Iteration number 13, -f(x) = 95127.5844, gradientNorm = 19.016173
# Iteration number 14, -f(x) = 95403.5887, gradientNorm = 18.160300
# Iteration number 15, -f(x) = 95664.7899, gradientNorm = 18.042263
# Iteration number 16, -f(x) = 95914.3587, gradientNorm = 17.526135
# Iteration number 17, -f(x) = 96162.1056, gradientNorm = 17.896029
# Iteration number 18, -f(x) = 96407.5955, gradientNorm = 17.465903
# Iteration number 19, -f(x) = 96656.7145, gradientNorm = 18.078893
# Iteration number 20, -f(x) = 96905.9233, gradientNorm = 17.510084
# Iteration number 21, -f(x) = 97158.2177, gradientNorm = 18.168385
# Iteration number 22, -f(x) = 97407.6825, gradientNorm = 17.313434
# Iteration number 23, -f(x) = 97655.5039, gradientNorm = 17.887421
# Iteration number 24, -f(x) = 97894.7709, gradientNorm = 16.700191
# Iteration number 25, -f(x) = 98126.1080, gradientNorm = 17.131998
# Iteration number 26, -f(x) = 98343.2060, gradientNorm = 15.657097
# Iteration number 27, -f(x) = 98547.1106, gradientNorm = 15.945644
# Iteration number 28, -f(x) = 98733.2252, gradientNorm = 14.283703
# Iteration number 29, -f(x) = 98903.3787, gradientNorm = 14.459695
# Iteration number 30, -f(x) = 99054.9687, gradientNorm = 12.726677
# Iteration number 31, -f(x) = 99190.4116, gradientNorm = 12.829171
# Iteration number 32, -f(x) = 99308.7396, gradientNorm = 11.126023
# Iteration number 33, -f(x) = 99412.5361, gradientNorm = 11.188097
# Iteration number 34, -f(x) = 99501.8740, gradientNorm = 9.586777
# Iteration number 35, -f(x) = 99579.1433, gradientNorm = 9.630689
# Iteration number 36, -f(x) = 99644.9300, gradientNorm = 8.173297
# Iteration number 37, -f(x) = 99701.2377, gradientNorm = 8.211429
# Iteration number 38, -f(x) = 99748.8130, gradientNorm = 6.916025
# Iteration number 39, -f(x) = 99789.2264, gradientNorm = 6.953884
# Iteration number 40, -f(x) = 99823.1957, gradientNorm = 5.821958
# Iteration number 41, -f(x) = 99851.8970, gradientNorm = 5.861080
# Iteration number 42, -f(x) = 99875.9401, gradientNorm = 4.884087
# Iteration number 43, -f(x) = 99896.1790, gradientNorm = 4.924107
# Iteration number 44, -f(x) = 99913.0974, gradientNorm = 4.088261
# Iteration number 45, -f(x) = 99927.3030, gradientNorm = 4.128147
# Iteration number 46, -f(x) = 99939.1637, gradientNorm = 3.417586
# Iteration number 47, -f(x) = 99949.1062, gradientNorm = 3.456270
# Iteration number 48, -f(x) = 99957.4028, gradientNorm = 2.854965
# Iteration number 49, -f(x) = 99964.3507, gradientNorm = 2.891604
# Iteration number 50, -f(x) = 99970.1477, gradientNorm = 2.384415
# Iteration number 51, -f(x) = 99974.9999, gradientNorm = 2.418458
# Iteration number 52, -f(x) = 99979.0492, gradientNorm = 1.991640
# Iteration number 53, -f(x) = 99982.4382, gradientNorm = 2.022802
# Iteration number 54, -f(x) = 99985.2677, gradientNorm = 1.664193
# Iteration number 55, -f(x) = 99987.6361, gradientNorm = 1.692401
# Iteration number 56, -f(x) = 99989.6149, gradientNorm = 1.391418
# Iteration number 57, -f(x) = 99991.2720, gradientNorm = 1.416744
# Iteration number 58, -f(x) = 99992.6577, gradientNorm = 1.164285
# Iteration number 59, -f(x) = 99993.8188, gradientNorm = 1.186899
# Iteration number 60, -f(x) = 99994.7908, gradientNorm = 0.975199
# Iteration number 61, -f(x) = 99995.6061, gradientNorm = 0.995323
# Iteration number 62, -f(x) = 99996.2893, gradientNorm = 0.817795
# Iteration number 63, -f(x) = 99996.8630, gradientNorm = 0.835676
# Iteration number 64, -f(x) = 99997.3446, gradientNorm = 0.686759
# Iteration number 65, -f(x) = 99997.7495, gradientNorm = 0.702647
# Iteration number 66, -f(x) = 99998.0898, gradientNorm = 0.577658
# Iteration number 67, -f(x) = 99998.3765, gradientNorm = 0.591792
# Iteration number 68, -f(x) = 99998.6180, gradientNorm = 0.486800
# Iteration number 69, -f(x) = 99998.8217, gradientNorm = 0.499401
# Iteration number 70, -f(x) = 99998.9937, gradientNorm = 0.411110
# Iteration number 71, -f(x) = 99999.1391, gradientNorm = 0.422378
# Iteration number 72, -f(x) = 99999.2621, gradientNorm = 0.348029
# Iteration number 73, -f(x) = 99999.3664, gradientNorm = 0.358140
# Iteration number 74, -f(x) = 99999.4549, gradientNorm = 0.295428
# Iteration number 75, -f(x) = 99999.5301, gradientNorm = 0.304535
# Iteration number 76, -f(x) = 99999.5941, gradientNorm = 0.251532
# Iteration number 77, -f(x) = 99999.6487, gradientNorm = 0.259767
# Iteration number 78, -f(x) = 99999.6953, gradientNorm = 0.214867
# Iteration number 79, -f(x) = 99999.7352, gradientNorm = 0.222340
# Iteration number 80, -f(x) = 99999.7693, gradientNorm = 0.184204
# Iteration number 81, -f(x) = 99999.7987, gradientNorm = 0.191010
# Iteration number 82, -f(x) = 99999.8239, gradientNorm = 0.158521
# Iteration number 83, -f(x) = 99999.8456, gradientNorm = 0.164738
# Iteration number 84, -f(x) = 99999.8644, gradientNorm = 0.136968
# Iteration number 85, -f(x) = 99999.8807, gradientNorm = 0.142661
# Iteration number 86, -f(x) = 99999.8948, gradientNorm = 0.118838
# Iteration number 87, -f(x) = 99999.9070, gradientNorm = 0.124062
# Iteration number 88, -f(x) = 99999.9177, gradientNorm = 0.103546
# Iteration number 89, -f(x) = 99999.9270, gradientNorm = 0.108346
# Iteration number 90, -f(x) = 99999.9351, gradientNorm = 0.090604
# Iteration number 91, -f(x) = 99999.9423, gradientNorm = 0.095019
# Iteration number 92, -f(x) = 99999.9485, gradientNorm = 0.079611
# Iteration number 93, -f(x) = 99999.9541, gradientNorm = 0.083673
# Iteration number 94, -f(x) = 99999.9589, gradientNorm = 0.070234
# Iteration number 95, -f(x) = 99999.9632, gradientNorm = 0.073972
# Iteration number 96, -f(x) = 99999.9670, gradientNorm = 0.062198
# Iteration number 97, -f(x) = 99999.9704, gradientNorm = 0.065637
# Iteration number 98, -f(x) = 99999.9734, gradientNorm = 0.055280
# Iteration number 99, -f(x) = 99999.9761, gradientNorm = 0.058442
# Iteration number 100, -f(x) = 99999.9784, gradientNorm = 0.049294
# Iteration number 101, -f(x) = 99999.9806, gradientNorm = 0.052199
# Iteration number 102, -f(x) = 99999.9825, gradientNorm = 0.044088
# Iteration number 103, -f(x) = 99999.9842, gradientNorm = 0.046756
# Iteration number 104, -f(x) = 99999.9857, gradientNorm = 0.039538
# Iteration number 105, -f(x) = 99999.9871, gradientNorm = 0.041987
# Iteration number 106, -f(x) = 99999.9883, gradientNorm = 0.035543
# Iteration number 107, -f(x) = 99999.9894, gradientNorm = 0.037788
# Iteration number 108, -f(x) = 99999.9904, gradientNorm = 0.032019
# Iteration number 109, -f(x) = 99999.9913, gradientNorm = 0.034076
# Iteration number 110, -f(x) = 99999.9921, gradientNorm = 0.028897
# Iteration number 111, -f(x) = 99999.9928, gradientNorm = 0.030780
# Iteration number 112, -f(x) = 99999.9935, gradientNorm = 0.026121
# Iteration number 113, -f(x) = 99999.9941, gradientNorm = 0.027844
# Iteration number 114, -f(x) = 99999.9946, gradientNorm = 0.023643
# Iteration number 115, -f(x) = 99999.9951, gradientNorm = 0.025220
# Iteration number 116, -f(x) = 99999.9956, gradientNorm = 0.021426
# Iteration number 117, -f(x) = 99999.9960, gradientNorm = 0.022867
# Iteration number 118, -f(x) = 99999.9963, gradientNorm = 0.019435
# Iteration number 119, -f(x) = 99999.9967, gradientNorm = 0.020752
# Iteration number 120, -f(x) = 99999.9970, gradientNorm = 0.017644
# Iteration number 121, -f(x) = 99999.9972, gradientNorm = 0.018848
# Iteration number 122, -f(x) = 99999.9975, gradientNorm = 0.016030
# Iteration number 123, -f(x) = 99999.9977, gradientNorm = 0.017129
# Iteration number 124, -f(x) = 99999.9979, gradientNorm = 0.014572
# Iteration number 125, -f(x) = 99999.9981, gradientNorm = 0.015575
# Iteration number 126, -f(x) = 99999.9983, gradientNorm = 0.013253
# Iteration number 127, -f(x) = 99999.9984, gradientNorm = 0.014168
# Iteration number 128, -f(x) = 99999.9986, gradientNorm = 0.012058
# Iteration number 129, -f(x) = 99999.9987, gradientNorm = 0.012894
# Iteration number 130, -f(x) = 99999.9988, gradientNorm = 0.010975
# Iteration number 131, -f(x) = 99999.9989, gradientNorm = 0.011737
# Iteration number 132, -f(x) = 99999.9990, gradientNorm = 0.009992
# Iteration number 133, -f(x) = 99999.9991, gradientNorm = 0.010687
# Iteration number 134, -f(x) = 99999.9992, gradientNorm = 0.009099
# Iteration number 135, -f(x) = 99999.9993, gradientNorm = 0.009734
# Iteration number 136, -f(x) = 99999.9993, gradientNorm = 0.008288
# Iteration number 137, -f(x) = 99999.9994, gradientNorm = 0.008867
# Iteration number 138, -f(x) = 99999.9994, gradientNorm = 0.007550
# Iteration number 139, -f(x) = 99999.9995, gradientNorm = 0.008078
# Iteration number 140, -f(x) = 99999.9995, gradientNorm = 0.006879
# Iteration number 141, -f(x) = 99999.9996, gradientNorm = 0.007360
# Iteration number 142, -f(x) = 99999.9996, gradientNorm = 0.006268
# Iteration number 143, -f(x) = 99999.9996, gradientNorm = 0.006707
# Iteration number 144, -f(x) = 99999.9997, gradientNorm = 0.005712
# Iteration number 145, -f(x) = 99999.9997, gradientNorm = 0.006113
# Iteration number 146, -f(x) = 99999.9997, gradientNorm = 0.005206
# Iteration number 147, -f(x) = 99999.9998, gradientNorm = 0.005571
# Iteration number 148, -f(x) = 99999.9998, gradientNorm = 0.004745
# Iteration number 149, -f(x) = 99999.9998, gradientNorm = 0.005078
# Iteration number 150, -f(x) = 99999.9998, gradientNorm = 0.004325
# Iteration number 151, -f(x) = 99999.9998, gradientNorm = 0.004628
# Iteration number 152, -f(x) = 99999.9998, gradientNorm = 0.003942
# Iteration number 153, -f(x) = 99999.9999, gradientNorm = 0.004219
# Iteration number 154, -f(x) = 99999.9999, gradientNorm = 0.003594
# Iteration number 155, -f(x) = 99999.9999, gradientNorm = 0.003846
# Iteration number 156, -f(x) = 99999.9999, gradientNorm = 0.003276
# Iteration number 157, -f(x) = 99999.9999, gradientNorm = 0.003506
# Iteration number 158, -f(x) = 99999.9999, gradientNorm = 0.002986
# Iteration number 159, -f(x) = 99999.9999, gradientNorm = 0.003196
# Iteration number 160, -f(x) = 99999.9999, gradientNorm = 0.002722
# Iteration number 161, -f(x) = 99999.9999, gradientNorm = 0.002914
# Iteration number 162, -f(x) = 99999.9999, gradientNorm = 0.002482
# Iteration number 163, -f(x) = 99999.9999, gradientNorm = 0.002656
# Iteration number 164, -f(x) = 99999.9999, gradientNorm = 0.002263
# Iteration number 165, -f(x) = 100000.0000, gradientNorm = 0.002422
# Iteration number 166, -f(x) = 100000.0000, gradientNorm = 0.002063
# Iteration number 167, -f(x) = 100000.0000, gradientNorm = 0.002208
# Iteration number 168, -f(x) = 100000.0000, gradientNorm = 0.001881
# Iteration number 169, -f(x) = 100000.0000, gradientNorm = 0.002013
# Iteration number 170, -f(x) = 100000.0000, gradientNorm = 0.001714
# Iteration number 171, -f(x) = 100000.0000, gradientNorm = 0.001835
# Iteration number 172, -f(x) = 100000.0000, gradientNorm = 0.001563
# Iteration number 173, -f(x) = 100000.0000, gradientNorm = 0.001673
# Iteration number 174, -f(x) = 100000.0000, gradientNorm = 0.001425
# Iteration number 175, -f(x) = 100000.0000, gradientNorm = 0.001525
# Iteration number 176, -f(x) = 100000.0000, gradientNorm = 0.001299
# Iteration number 177, -f(x) = 100000.0000, gradientNorm = 0.001391
# Iteration number 178, -f(x) = 100000.0000, gradientNorm = 0.001185
# Iteration number 179, -f(x) = 100000.0000, gradientNorm = 0.001268
# Iteration number 180, -f(x) = 100000.0000, gradientNorm = 0.001080
# Iteration number 181, -f(x) = 100000.0000, gradientNorm = 0.001156
# Iteration number 182, -f(x) = 100000.0000, gradientNorm = 0.000985
# Iteration number 183, -f(x) = 100000.0000, gradientNorm = 0.001054
# Iteration number 184, -f(x) = 100000.0000, gradientNorm = 0.000898
# Iteration number 185, -f(x) = 100000.0000, gradientNorm = 0.000961
# Iteration number 186, -f(x) = 100000.0000, gradientNorm = 0.000818
# Iteration number 187, -f(x) = 100000.0000, gradientNorm = 0.000876
# Iteration number 188, -f(x) = 100000.0000, gradientNorm = 0.000746
# Iteration number 189, -f(x) = 100000.0000, gradientNorm = 0.000799
# Iteration number 190, -f(x) = 100000.0000, gradientNorm = 0.000680
# Iteration number 191, -f(x) = 100000.0000, gradientNorm = 0.000728
# Iteration number 192, -f(x) = 100000.0000, gradientNorm = 0.000620
# Iteration number 193, -f(x) = 100000.0000, gradientNorm = 0.000664
# Iteration number 194, -f(x) = 100000.0000, gradientNorm = 0.000565
# Iteration number 195, -f(x) = 100000.0000, gradientNorm = 0.000605
# Iteration number 196, -f(x) = 100000.0000, gradientNorm = 0.000516
# Iteration number 197, -f(x) = 100000.0000, gradientNorm = 0.000552
# Iteration number 198, -f(x) = 100000.0000, gradientNorm = 0.000470
# Iteration number 199, -f(x) = 100000.0000, gradientNorm = 0.000503
# Iteration number 200, -f(x) = 100000.0000, gradientNorm = 0.000429
# Iteration number 201, -f(x) = 100000.0000, gradientNorm = 0.000459
# Iteration number 202, -f(x) = 100000.0000, gradientNorm = 0.000391
# Iteration number 203, -f(x) = 100000.0000, gradientNorm = 0.000418
# Iteration number 204, -f(x) = 100000.0000, gradientNorm = 0.000356
# Iteration number 205, -f(x) = 100000.0000, gradientNorm = 0.000381
# Iteration number 206, -f(x) = 100000.0000, gradientNorm = 0.000325
# Iteration number 207, -f(x) = 100000.0000, gradientNorm = 0.000348
# Iteration number 208, -f(x) = 100000.0000, gradientNorm = 0.000296
# Iteration number 209, -f(x) = 100000.0000, gradientNorm = 0.000317
# Iteration number 210, -f(x) = 100000.0000, gradientNorm = 0.000270
# Iteration number 211, -f(x) = 100000.0000, gradientNorm = 0.000289
# Iteration number 212, -f(x) = 100000.0000, gradientNorm = 0.000246
# Iteration number 213, -f(x) = 100000.0000, gradientNorm = 0.000263
# Iteration number 214, -f(x) = 100000.0000, gradientNorm = 0.000224
# Iteration number 215, -f(x) = 100000.0000, gradientNorm = 0.000240
# Iteration number 216, -f(x) = 100000.0000, gradientNorm = 0.000205
# Iteration number 217, -f(x) = 100000.0000, gradientNorm = 0.000219
# Iteration number 218, -f(x) = 100000.0000, gradientNorm = 0.000187
# Iteration number 219, -f(x) = 100000.0000, gradientNorm = 0.000200
# Iteration number 220, -f(x) = 100000.0000, gradientNorm = 0.000170
# Iteration number 221, -f(x) = 100000.0000, gradientNorm = 0.000182
# Iteration number 222, -f(x) = 100000.0000, gradientNorm = 0.000155
# Iteration number 223, -f(x) = 100000.0000, gradientNorm = 0.000166
# Iteration number 224, -f(x) = 100000.0000, gradientNorm = 0.000141
# Iteration number 225, -f(x) = 100000.0000, gradientNorm = 0.000151
# Iteration number 226, -f(x) = 100000.0000, gradientNorm = 0.000129
# Iteration number 227, -f(x) = 100000.0000, gradientNorm = 0.000138
# Iteration number 228, -f(x) = 100000.0000, gradientNorm = 0.000118
# Iteration number 229, -f(x) = 100000.0000, gradientNorm = 0.000126
# Iteration number 230, -f(x) = 100000.0000, gradientNorm = 0.000107
# Iteration number 231, -f(x) = 100000.0000, gradientNorm = 0.000115
# Iteration number 232, -f(x) = 100000.0000, gradientNorm = 0.000098
# Iteration number 233, -f(x) = 100000.0000, gradientNorm = 0.000105
# Iteration number 234, -f(x) = 100000.0000, gradientNorm = 0.000089
# Iteration number 235, -f(x) = 100000.0000, gradientNorm = 0.000095
# Iteration number 236, -f(x) = 100000.0000, gradientNorm = 0.000081
# Iteration number 237, -f(x) = 100000.0000, gradientNorm = 0.000087
# Iteration number 238, -f(x) = 100000.0000, gradientNorm = 0.000074
# Iteration number 239, -f(x) = 100000.0000, gradientNorm = 0.000079
# Iteration number 240, -f(x) = 100000.0000, gradientNorm = 0.000068
# Iteration number 241, -f(x) = 100000.0000, gradientNorm = 0.000072
# Iteration number 242, -f(x) = 100000.0000, gradientNorm = 0.000062
# Iteration number 243, -f(x) = 100000.0000, gradientNorm = 0.000066
# Iteration number 244, -f(x) = 100000.0000, gradientNorm = 0.000056
# Iteration number 245, -f(x) = 100000.0000, gradientNorm = 0.000060
# Iteration number 246, -f(x) = 100000.0000, gradientNorm = 0.000051
# Iteration number 247, -f(x) = 100000.0000, gradientNorm = 0.000055
# Iteration number 248, -f(x) = 100000.0000, gradientNorm = 0.000047
# Iteration number 249, -f(x) = 100000.0000, gradientNorm = 0.000050
# Iteration number 250, -f(x) = 100000.0000, gradientNorm = 0.000043
# Iteration number 251, -f(x) = 100000.0000, gradientNorm = 0.000046
# Iteration number 252, -f(x) = 100000.0000, gradientNorm = 0.000039
# Iteration number 253, -f(x) = 100000.0000, gradientNorm = 0.000042
# Iteration number 254, -f(x) = 100000.0000, gradientNorm = 0.000035
# Iteration number 255, -f(x) = 100000.0000, gradientNorm = 0.000038
# Iteration number 256, -f(x) = 100000.0000, gradientNorm = 0.000032
# Iteration number 257, -f(x) = 100000.0000, gradientNorm = 0.000034
# Iteration number 258, -f(x) = 100000.0000, gradientNorm = 0.000029
# Iteration number 259, -f(x) = 100000.0000, gradientNorm = 0.000031
# Iteration number 260, -f(x) = 100000.0000, gradientNorm = 0.000027
# Iteration number 261, -f(x) = 100000.0000, gradientNorm = 0.000029
# Iteration number 262, -f(x) = 100000.0000, gradientNorm = 0.000024
# Iteration number 263, -f(x) = 100000.0000, gradientNorm = 0.000026
# Iteration number 264, -f(x) = 100000.0000, gradientNorm = 0.000022
# Iteration number 265, -f(x) = 100000.0000, gradientNorm = 0.000024
# Iteration number 266, -f(x) = 100000.0000, gradientNorm = 0.000020
# Iteration number 267, -f(x) = 100000.0000, gradientNorm = 0.000022
# Iteration number 268, -f(x) = 100000.0000, gradientNorm = 0.000019
# Iteration number 269, -f(x) = 100000.0000, gradientNorm = 0.000020
# Iteration number 270, -f(x) = 100000.0000, gradientNorm = 0.000017
# Iteration number 271, -f(x) = 100000.0000, gradientNorm = 0.000018
# Iteration number 272, -f(x) = 100000.0000, gradientNorm = 0.000015
# Iteration number 273, -f(x) = 100000.0000, gradientNorm = 0.000016
# Iteration number 274, -f(x) = 100000.0000, gradientNorm = 0.000014
# Iteration number 275, -f(x) = 100000.0000, gradientNorm = 0.000015
# Iteration number 276, -f(x) = 100000.0000, gradientNorm = 0.000013
# Iteration number 277, -f(x) = 100000.0000, gradientNorm = 0.000014
# Iteration number 278, -f(x) = 100000.0000, gradientNorm = 0.000012
# Iteration number 279, -f(x) = 100000.0000, gradientNorm = 0.000012
# Iteration number 280, -f(x) = 100000.0000, gradientNorm = 0.000011
# Iteration number 281, -f(x) = 100000.0000, gradientNorm = 0.000011
# Iteration number 282, -f(x) = 100000.0000, gradientNorm = 0.000010

# %%
norm = la.norm(M5, ord=2) ** 2

# %%
norm
# Out:
# 100000.00000006477

# %%
# Norm and errors SGD
normsCG = np.array(normsCG)
gradientsCG.insert(0,np.array(gradientCG))
size1 = normsCG.size

# %%
normvec = np.ones(size1) * norm
errorsCG.insert(0, (abs(normsCG - normvec) / abs(normvec)))

# %%
errorsCG[-1][-1]
# Out:
# 8.440110832447307e-15

# %%
make_plot(gradientsCG, errorsCG, type='M5', experiment_name='exp1-M5')

# %% [raw]
# %%timeit -r 100 -n 10
# # Optimizer SGD
# f = nf.normFunction(M5)
# optimizerCG = CG.conjugateGradient(f, 1e-5, 500, method='HS', x=initial_vector, verbose = False)
# gradientCG, normsCG = optimizerCG.ConjugateGradient()

# %% [raw]
# from scipy.optimize import minimize

# %% [raw]
# %%timeit -r 100 -n 10
# res = minimize(f.func_, initial_vector, method='CG', tol=1e-5)
# value = -res.fun
